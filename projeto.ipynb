# %%
# Importações básicas
import os
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql import DataFrame
from pyspark.sql import functions as F
from pyspark.sql.types import StructType,StructField, StringType, IntegerType, FloatType, DateType
from datetime import date, timedelta, datetime
import random
import calendar
from dateutil.relativedelta import relativedelta
import logging

# %%
logging.basicConfig(level=logging.INFO, filename="teste.log")

# %%
# Lista de clientes
nome_cliente = [
    "Ana", "João", "Maria", "Pedro", "Júlia", "Lucas", "Larissa", "Gabriel", "Beatriz", "Felipe", "Clara",
    "Daniel", "Laura", "Rafael", "Mariana", "Gustavo", "Luísa", "Henrique", "Sofia", "Matheus", "Isabella",
    "Bruno", "Alice", "Thiago", "Helena", "Rodrigo", "Giovanna", "Eduardo", "Rafaela", "Leonardo", "Nicole",
    "Caio", "Vitória", "André", "Fernanda", "Diego", "Yasmin", "Guilherme", "Letícia", "Vinícius", "Camila",
    "Igor", "Valentina", "Otávio", "Bianca", "Enzo", "Lorena", "Alex", "Elisa", "Murilo", "Vitória", "Samuel",
    "Gabriela", "Arthur", "Evelyn", "Miguel", "Marina", "Renan", "Tainá", "Jorge", "Juliana", "Samuel",
    "Melissa", "Raul", "Camila", "Levi", "Carolina", "Nathan", "Cecília", "Lucas", "Amanda", "Benjamin",
    "Lívia", "Heitor", "Bruna", "Davi", "Talita", "Theo", "Maíra", "Tomás", "Ana Clara", "Vicente", "Isadora",
    "Alexandre", "Sabrina", "Emerson", "Thaís", "Renata", "Otávio", "Priscila", "Eduardo", "Natália", "Jonas",
    "Aline", "Cristiano", "Patrícia", "Vicente", "Elisa"
]

# Lista de estados e cidades
estado_cidade = {
    "AC": ["Rio Branco", "Cruzeiro do Sul", "Sena Madureira"],
    "AL": ["Maceió", "Arapiraca", "Palmeira dos Índios"],
    "AP": ["Macapá", "Santana", "Laranjal do Jari"],
    "AM": ["Manaus", "Parintins", "Itacoatiara"],
    "BA": ["Salvador", "Feira de Santana", "Vitória da Conquista"],
    "CE": ["Fortaleza", "Caucaia", "Juazeiro do Norte"],
    "DF": ["Brasília"],
    "ES": ["Vitória", "Vila Velha", "Serra"],
    "GO": ["Goiânia", "Anápolis", "Aparecida de Goiânia"],
    "MA": ["São Luís", "Imperatriz", "Timon"],
    "MT": ["Cuiabá", "Várzea Grande", "Rondonópolis"],
    "MS": ["Campo Grande", "Dourados", "Três Lagoas"],
    "MG": ["Belo Horizonte", "Uberlândia", "Contagem"],
    "PA": ["Belém", "Ananindeua", "Santarém"],
    "PB": ["João Pessoa", "Campina Grande", "Santa Rita"],
    "PR": ["Curitiba", "Londrina", "Maringá"],
    "PE": ["Recife", "Jaboatão dos Guararapes", "Olinda"],
    "PI": ["Teresina", "Parnaíba", "Picos"],
    "RJ": ["Rio de Janeiro", "Niterói", "Duque de Caxias"],
    "RN": ["Natal", "Mossoró", "Parnamirim"],
    "RS": ["Porto Alegre", "Caxias do Sul", "Pelotas"],
    "RO": ["Porto Velho", "Ji-Paraná", "Ariquemes"],
    "RR": ["Boa Vista", "Rorainópolis", "Caracaraí"],
    "SC": ["Florianópolis", "Joinville", "Blumenau"],
    "SP": ["São Paulo", "Campinas", "São Bernardo do Campo"],
    "SE": ["Aracaju", "Nossa Senhora do Socorro", "Lagarto"],
    "TO": ["Palmas", "Araguaína", "Gurupi"]
}

# Lista de produtos eletrônicos
produtos = ["Smartphone", "Notebook", "Tablet", "Monitor", "Fone de Ouvido", "Smartwatch", "Câmera", "Impressora", "Caixa de Som", "Roteador"]

# %%
print(len(nome_cliente))
print(len(estado_cidade))
print(len(produtos))
# Out:
# 98
# 27
# 10

# %%
def gerardados(nome_cliente, estado_cidade, produtos):

    vendas = []
        
# Gera dados para número do pedido e código do cliente
    for dados in range(1,101):

        nrpedido = dados
        codcliente = random.randint(1, 100)  
        cliente = random.choice(nome_cliente)      
        qtd =  random.randint(1, 100)
        produto = random.choice(produtos)
        custo = float(round(random.uniform(1.00, 100.00),2))
        valor_venda = float(round(qtd * (custo * random.uniform(1.5, 8.0)), 2)) # Escolhe uma margem de lucro entre 1.5 e 8.0.
        data_inicial = date.today() - relativedelta(years=5)  # Captura a data atual e subtrai 5 anos.
        data_final = date.today()
        # Listando o período de data inicial e data final
        datas = [data_inicial + timedelta(days=i) for i in range((data_final - data_inicial).days + 1)]
        data = random.choice(datas)

        uf = random.choice(list(estado_cidade.keys()))
        cidade = random.choice(estado_cidade[uf])
        vendas.append((nrpedido, codcliente, cliente, qtd, produto, custo, valor_venda, uf, cidade, data))

    return vendas

# %%
gerardados(nome_cliente, estado_cidade, produtos)
# Out:
# [(1,
#   87,
#   'Camila',
#   63,
#   'Smartphone',
#   79.9,
#   11952.4,
#   'PR',
#   'Londrina',
#   datetime.date(2023, 10, 18)),
#  (2,
#   57,
#   'Carolina',
#   12,
#   'Smartphone',
#   67.64,
#   5626.91,
#   'AP',
#   'Santana',
#   datetime.date(2022, 11, 8)),
#  (3,
#   73,
#   'Jonas',
#   26,
#   'Câmera',
#   30.58,
#   4162.71,
#   'MT',
#   'Rondonópolis',
#   datetime.date(2025, 8, 26)),
#  (4,
#   41,
#   'Sofia',
#   12,
#   'Impressora',
#   91.93,
#   3459.24,
#   'AM',
#   'Manaus',
#   datetime.date(2023, 10, 26)),
#  (5,
#   23,
#   'Patrícia',
#   93,
#   'Caixa de Som',
#   87.68,
#   50028.68,
#   'SC',
#   'Joinville',
#   datetime.date(2020, 9, 28)),
#  (6,
#   65,
#   'Melissa',
#   99,
#   'Fone de Ouvido',
#   44.04,
#   24841.53,
#   'GO',
#   'Goiânia',
#   datetime.date(2024, 10, 12)),
#  (7,
#   74,
#   'Cristiano',
#   53,
#   'Monitor',
#   98.32,
#   10469.33,
#   'MG',
#   'Uberlândia',
#   datetime.date(2024, 3, 19)),
#  (8,
#   48,
#   'Ana',
#   19,
#   'Impressora',
#   66.96,
#   7366.13,
#   'MG',
#   'Belo Horizonte',
#   datetime.date(2021, 9, 6)),
#  (9,
#   69,
#   'Gabriel',
#   61,
#   'Impressora',
#   29.33,
#   7444.44,
#   'AL',
#   'Maceió',
#   datetime.date(2022, 7, 15)),
#  (10,
#   81,
#   'Rodrigo',
#   50,
#   'Smartphone',
#   91.47,
#   9744.72,
#   'MS',
#   'Campo Grande',
#   datetime.date(2025, 1, 10)),
#  (11,
#   58,
#   'Murilo',
#   96,
#   'Câmera',
#   38.45,
#   9050.58,
#   'ES',
#   'Serra',
#   datetime.date(2024, 4, 21)),
#  (12,
#   84,
#   'Nicole',
#   70,
#   'Câmera',
#   99.61,
#   49200.63,
#   'GO',
#   'Goiânia',
#   datetime.date(2023, 10, 13)),
#  (13,
#   72,
#   'Benjamin',
#   99,
#   'Fone de Ouvido',
#   68.71,
#   51427.25,
#   'MT',
#   'Rondonópolis',
#   datetime.date(2022, 10, 9)),
#  (14,
#   79,
#   'Rafael',
#   6,
#   'Roteador',
#   35.32,
#   421.62,
#   'SC',
#   'Joinville',
#   datetime.date(2023, 6, 4)),
#  (15,
#   31,
#   'Gustavo',
#   86,
#   'Impressora',
#   84.4,
#   45729.77,
#   'RN',
#   'Mossoró',
#   datetime.date(2023, 9, 26)),
#  (16,
#   47,
#   'Evelyn',
#   95,
#   'Smartphone',
#   89.26,
#   35957.84,
#   'RO',
#   'Ariquemes',
#   datetime.date(2021, 5, 7)),
#  (17,
#   100,
#   'Renan',
#   87,
#   'Smartphone',
#   95.04,
#   41864.56,
#   'GO',
#   'Goiânia',
#   datetime.date(2021, 9, 13)),
#  (18,
#   61,
#   'Clara',
#   10,
#   'Fone de Ouvido',
#   45.85,
#   2600.82,
#   'RS',
#   'Pelotas',
#   datetime.date(2022, 2, 8)),
#  (19,
#   56,
#   'Marina',
#   23,
#   'Fone de Ouvido',
#   93.77,
#   16026.13,
#   'RJ',
#   'Duque de Caxias',
#   datetime.date(2024, 12, 2)),
#  (20,
#   26,
#   'Bruno',
#   95,
#   'Caixa de Som',
#   7.17,
#   3097.69,
#   'RN',
#   'Mossoró',
#   datetime.date(2024, 3, 22)),
#  (21,
#   60,
#   'Laura',
#   4,
#   'Smartwatch',
#   32.07,
#   507.6,
#   'AL',
#   'Maceió',
#   datetime.date(2020, 10, 29)),
#  (22,
#   65,
#   'Levi',
#   83,
#   'Roteador',
#   42.28,
#   19140.67,
#   'AM',
#   'Manaus',
#   datetime.date(2021, 9, 6)),
#  (23,
#   49,
#   'Jorge',
#   99,
#   'Caixa de Som',
#   99.24,
#   61246.02,
#   'PA',
#   'Ananindeua',
#   datetime.date(2024, 6, 25)),
#  (24,
#   61,
#   'Enzo',
#   38,
#   'Câmera',
#   45.35,
#   6213.09,
#   'SE',
#   'Aracaju',
#   datetime.date(2023, 4, 30)),
#  (25,
#   8,
#   'Murilo',
#   28,
#   'Monitor',
#   19.65,
#   3915.61,
#   'AM',
#   'Itacoatiara',
#   datetime.date(2021, 10, 23)),
#  (26,
#   44,
#   'Letícia',
#   35,
#   'Monitor',
#   92.83,
#   7760.3,
#   'PR',
#   'Maringá',
#   datetime.date(2021, 12, 27)),
#  (27,
#   30,
#   'Nicole',
#   13,
#   'Smartphone',
#   41.26,
#   843.25,
#   'RR',
#   'Boa Vista',
#   datetime.date(2024, 2, 28)),
#  (28,
#   39,
#   'Alexandre',
#   34,
#   'Smartphone',
#   26.56,
#   1732.97,
#   'RJ',
#   'Niterói',
#   datetime.date(2022, 8, 22)),
#  (29,
#   22,
#   'Matheus',
#   86,
#   'Monitor',
#   82.47,
#   34749.14,
#   'RO',
#   'Ji-Paraná',
#   datetime.date(2022, 6, 14)),
#  (30,
#   1,
#   'Gabriela',
#   38,
#   'Notebook',
#   16.07,
#   2334.51,
#   'AM',
#   'Parintins',
#   datetime.date(2023, 12, 26)),
#  (31,
#   51,
#   'João',
#   7,
#   'Roteador',
#   38.19,
#   630.48,
#   'CE',
#   'Juazeiro do Norte',
#   datetime.date(2025, 3, 30)),
#  (32,
#   19,
#   'Cristiano',
#   58,
#   'Roteador',
#   19.36,
#   4388.88,
#   'RJ',
#   'Niterói',
#   datetime.date(2022, 11, 19)),
#  (33,
#   84,
#   'Vitória',
#   94,
#   'Câmera',
#   34.63,
#   23708.34,
#   'PI',
#   'Parnaíba',
#   datetime.date(2022, 1, 1)),
#  (34,
#   67,
#   'Igor',
#   100,
#   'Smartwatch',
#   56.57,
#   31352.59,
#   'GO',
#   'Anápolis',
#   datetime.date(2024, 6, 17)),
#  (35,
#   46,
#   'Vinícius',
#   68,
#   'Caixa de Som',
#   46.67,
#   22720.35,
#   'AC',
#   'Rio Branco',
#   datetime.date(2024, 3, 8)),
#  (36,
#   20,
#   'Rafael',
#   82,
#   'Tablet',
#   96.99,
#   31153.01,
#   'SP',
#   'São Bernardo do Campo',
#   datetime.date(2023, 6, 2)),
#  (37,
#   95,
#   'Laura',
#   90,
#   'Smartwatch',
#   91.94,
#   65939.73,
#   'SP',
#   'Campinas',
#   datetime.date(2022, 7, 28)),
#  (38,
#   34,
#   'Rafael',
#   65,
#   'Roteador',
#   32.27,
#   11993.68,
#   'CE',
#   'Juazeiro do Norte',
#   datetime.date(2022, 5, 28)),
#  (39,
#   38,
#   'Isadora',
#   35,
#   'Tablet',
#   37.16,
#   9615.26,
#   'RR',
#   'Caracaraí',
#   datetime.date(2024, 7, 6)),
#  (40,
#   8,
#   'Gabriel',
#   12,
#   'Câmera',
#   24.04,
#   724.32,
#   'SC',
#   'Florianópolis',
#   datetime.date(2025, 4, 11)),
#  (41,
#   93,
#   'Enzo',
#   2,
#   'Caixa de Som',
#   73.93,
#   519.79,
#   'RO',
#   'Porto Velho',
#   datetime.date(2025, 8, 6)),
#  (42,
#   76,
#   'Ana',
#   10,
#   'Notebook',
#   54.55,
#   1464.44,
#   'RR',
#   'Caracaraí',
#   datetime.date(2022, 9, 16)),
#  (43,
#   71,
#   'Eduardo',
#   78,
#   'Fone de Ouvido',
#   99.21,
#   55003.81,
#   'PA',
#   'Belém',
#   datetime.date(2021, 4, 30)),
#  (44,
#   7,
#   'Mariana',
#   98,
#   'Smartwatch',
#   86.79,
#   14274.68,
#   'AP',
#   'Santana',
#   datetime.date(2021, 12, 24)),
#  (45,
#   94,
#   'Camila',
#   58,
#   'Smartphone',
#   61.63,
#   11809.98,
#   'PA',
#   'Belém',
#   datetime.date(2022, 1, 3)),
#  (46,
#   60,
#   'Patrícia',
#   40,
#   'Notebook',
#   18.61,
#   4316.32,
#   'MT',
#   'Cuiabá',
#   datetime.date(2022, 6, 19)),
#  (47,
#   32,
#   'Mariana',
#   97,
#   'Tablet',
#   75.32,
#   42842.41,
#   'AP',
#   'Laranjal do Jari',
#   datetime.date(2024, 6, 14)),
#  (48,
#   17,
#   'Bruno',
#   54,
#   'Fone de Ouvido',
#   46.83,
#   10441.15,
#   'TO',
#   'Araguaína',
#   datetime.date(2021, 6, 26)),
#  (49,
#   21,
#   'Jorge',
#   21,
#   'Monitor',
#   32.59,
#   3699.17,
#   'RO',
#   'Porto Velho',
#   datetime.date(2024, 1, 24)),
#  (50,
#   96,
#   'Jorge',
#   11,
#   'Câmera',
#   3.88,
#   100.88,
#   'AL',
#   'Arapiraca',
#   datetime.date(2025, 3, 26)),
#  (51,
#   13,
#   'Gustavo',
#   42,
#   'Caixa de Som',
#   65.1,
#   8088.84,
#   'RS',
#   'Porto Alegre',
#   datetime.date(2024, 9, 13)),
#  (52,
#   43,
#   'Tomás',
#   14,
#   'Roteador',
#   38.28,
#   3110.56,
#   'DF',
#   'Brasília',
#   datetime.date(2023, 2, 8)),
#  (53,
#   57,
#   'Isadora',
#   1,
#   'Caixa de Som',
#   53.62,
#   188.44,
#   'SC',
#   'Joinville',
#   datetime.date(2025, 2, 4)),
#  (54,
#   32,
#   'Renan',
#   92,
#   'Roteador',
#   56.23,
#   24671.93,
#   'SC',
#   'Florianópolis',
#   datetime.date(2025, 6, 27)),
#  (55,
#   62,
#   'Gabriela',
#   68,
#   'Tablet',
#   38.17,
#   17108.56,
#   'CE',
#   'Fortaleza',
#   datetime.date(2020, 11, 26)),
#  (56,
#   24,
#   'Levi',
#   55,
#   'Câmera',
#   14.52,
#   2014.08,
#   'MS',
#   'Campo Grande',
#   datetime.date(2024, 7, 10)),
#  (57,
#   44,
#   'Otávio',
#   94,
#   'Caixa de Som',
#   76.12,
#   46631.43,
#   'PB',
#   'Santa Rita',
#   datetime.date(2021, 7, 24)),
#  (58,
#   98,
#   'Daniel',
#   26,
#   'Caixa de Som',
#   53.83,
#   2189.97,
#   'MG',
#   'Uberlândia',
#   datetime.date(2024, 10, 18)),
#  (59,
#   54,
#   'Aline',
#   87,
#   'Tablet',
#   29.43,
#   10331.68,
#   'DF',
#   'Brasília',
#   datetime.date(2023, 9, 3)),
#  (60,
#   60,
#   'Felipe',
#   7,
#   'Câmera',
#   48.19,
#   1684.66,
#   'RN',
#   'Mossoró',
#   datetime.date(2021, 11, 14)),
#  (61,
#   76,
#   'Elisa',
#   25,
#   'Monitor',
#   66.95,
#   8178.97,
#   'SP',
#   'São Bernardo do Campo',
#   datetime.date(2021, 12, 6)),
#  (62,
#   56,
#   'Arthur',
#   36,
#   'Câmera',
#   28.11,
#   1524.07,
#   'GO',
#   'Anápolis',
#   datetime.date(2024, 8, 12)),
#  (63,
#   13,
#   'Lucas',
#   24,
#   'Monitor',
#   9.97,
#   378.73,
#   'PI',
#   'Picos',
#   datetime.date(2023, 6, 17)),
#  (64,
#   77,
#   'Heitor',
#   95,
#   'Roteador',
#   88.77,
#   23704.2,
#   'RO',
#   'Ji-Paraná',
#   datetime.date(2024, 1, 13)),
#  (65,
#   2,
#   'Bruna',
#   90,
#   'Notebook',
#   29.15,
#   12372.56,
#   'DF',
#   'Brasília',
#   datetime.date(2022, 2, 3)),
#  (66,
#   58,
#   'Renata',
#   32,
#   'Roteador',
#   87.99,
#   4734.14,
#   'AC',
#   'Sena Madureira',
#   datetime.date(2024, 3, 6)),
#  (67,
#   1,
#   'Thiago',
#   86,
#   'Smartphone',
#   8.66,
#   5939.07,
#   'ES',
#   'Vitória',
#   datetime.date(2024, 3, 18)),
#  (68,
#   39,
#   'Caio',
#   54,
#   'Roteador',
#   98.15,
#   40839.89,
#   'DF',
#   'Brasília',
#   datetime.date(2023, 7, 28)),
#  (69,
#   53,
#   'Thiago',
#   61,
#   'Câmera',
#   88.2,
#   32060.33,
#   'AP',
#   'Laranjal do Jari',
#   datetime.date(2021, 6, 12)),
#  (70,
#   98,
#   'Talita',
#   21,
#   'Notebook',
#   62.79,
#   3667.62,
#   'AL',
#   'Maceió',
#   datetime.date(2022, 11, 16)),
#  (71,
#   31,
#   'Vicente',
#   85,
#   'Fone de Ouvido',
#   28.27,
#   18916.44,
#   'BA',
#   'Salvador',
#   datetime.date(2025, 1, 29)),
#  (72,
#   97,
#   'Renan',
#   16,
#   'Tablet',
#   6.48,
#   734.36,
#   'SP',
#   'São Bernardo do Campo',
#   datetime.date(2024, 5, 15)),
#  (73,
#   94,
#   'Isabella',
#   34,
#   'Notebook',
#   31.56,
#   2063.33,
#   'BA',
#   'Vitória da Conquista',
#   datetime.date(2024, 6, 16)),
#  (74,
#   7,
#   'Emerson',
#   13,
#   'Impressora',
#   64.41,
#   1839.17,
#   'RN',
#   'Natal',
#   datetime.date(2024, 11, 12)),
#  (75,
#   55,
#   'Nathan',
#   72,
#   'Câmera',
#   7.83,
#   1129.33,
#   'MG',
#   'Uberlândia',
#   datetime.date(2024, 9, 20)),
#  (76,
#   78,
#   'Ana',
#   19,
#   'Smartwatch',
#   63.7,
#   7415.55,
#   'GO',
#   'Goiânia',
#   datetime.date(2021, 1, 31)),
#  (77,
#   98,
#   'Sofia',
#   55,
#   'Notebook',
#   90.82,
#   32227.29,
#   'BA',
#   'Feira de Santana',
#   datetime.date(2023, 2, 6)),
#  (78,
#   37,
#   'Cristiano',
#   56,
#   'Roteador',
#   9.41,
#   3423.61,
#   'AL',
#   'Maceió',
#   datetime.date(2023, 2, 15)),
#  (79,
#   59,
#   'Sabrina',
#   63,
#   'Monitor',
#   53.61,
#   14831.34,
#   'TO',
#   'Gurupi',
#   datetime.date(2025, 6, 18)),
#  (80,
#   71,
#   'Ana',
#   100,
#   'Notebook',
#   31.99,
#   25111.18,
#   'SC',
#   'Florianópolis',
#   datetime.date(2020, 10, 3)),
#  (81,
#   96,
#   'Thaís',
#   78,
#   'Fone de Ouvido',
#   14.29,
#   4398.21,
#   'RN',
#   'Natal',
#   datetime.date(2024, 11, 24)),
#  (82,
#   90,
#   'Renata',
#   97,
#   'Monitor',
#   91.69,
#   52537.43,
#   'SP',
#   'Campinas',
#   datetime.date(2022, 3, 17)),
#  (83,
#   85,
#   'Gabriel',
#   71,
#   'Câmera',
#   86.55,
#   13643.02,
#   'PB',
#   'Santa Rita',
#   datetime.date(2022, 6, 4)),
#  (84,
#   3,
#   'Felipe',
#   92,
#   'Caixa de Som',
#   62.95,
#   28501.54,
#   'AL',
#   'Arapiraca',
#   datetime.date(2022, 12, 27)),
#  (85,
#   32,
#   'Gabriel',
#   38,
#   'Smartphone',
#   84.91,
#   24329.63,
#   'ES',
#   'Vitória',
#   datetime.date(2025, 6, 26)),
#  (86,
#   54,
#   'Maíra',
#   72,
#   'Roteador',
#   13.34,
#   7330.85,
#   'CE',
#   'Fortaleza',
#   datetime.date(2021, 12, 30)),
#  (87,
#   1,
#   'Tainá',
#   11,
#   'Roteador',
#   37.79,
#   1692.88,
#   'RN',
#   'Natal',
#   datetime.date(2022, 9, 11)),
#  (88,
#   36,
#   'Diego',
#   90,
#   'Smartphone',
#   92.0,
#   29425.96,
#   'MG',
#   'Uberlândia',
#   datetime.date(2021, 11, 19)),
#  (89,
#   22,
#   'Benjamin',
#   33,
#   'Monitor',
#   39.88,
#   7804.34,
#   'PI',
#   'Teresina',
#   datetime.date(2020, 11, 2)),
#  (90,
#   2,
#   'Talita',
#   10,
#   'Impressora',
#   86.14,
#   4276.82,
#   'TO',
#   'Palmas',
#   datetime.date(2025, 1, 13)),
#  (91,
#   14,
#   'Alice',
#   4,
#   'Smartphone',
#   44.83,
#   1180.0,
#   'RS',
#   'Caxias do Sul',
#   datetime.date(2025, 1, 16)),
#  (92,
#   64,
#   'Bruno',
#   85,
#   'Roteador',
#   98.84,
#   26594.76,
#   'TO',
#   'Palmas',
#   datetime.date(2025, 3, 25)),
#  (93,
#   25,
#   'Vicente',
#   90,
#   'Fone de Ouvido',
#   6.57,
#   3325.16,
#   'SP',
#   'Campinas',
#   datetime.date(2022, 10, 25)),
#  (94,
#   86,
#   'Larissa',
#   31,
#   'Impressora',
#   24.18,
#   1775.51,
#   'TO',
#   'Palmas',
#   datetime.date(2023, 6, 12)),
#  (95,
#   43,
#   'Mariana',
#   67,
#   'Impressora',
#   40.98,
#   11662.68,
#   'RO',
#   'Ariquemes',
#   datetime.date(2021, 9, 24)),
#  (96,
#   80,
#   'Evelyn',
#   17,
#   'Monitor',
#   89.61,
#   11560.98,
#   'MA',
#   'Timon',
#   datetime.date(2021, 11, 14)),
#  (97,
#   32,
#   'Ana Clara',
#   81,
#   'Roteador',
#   87.28,
#   31255.02,
#   'SE',
#   'Nossa Senhora do Socorro',
#   datetime.date(2021, 12, 29)),
#  (98,
#   82,
#   'Priscila',
#   38,
#   'Fone de Ouvido',
#   3.22,
#   559.26,
#   'SP',
#   'São Bernardo do Campo',
#   datetime.date(2021, 5, 18)),
#  (99,
#   51,
#   'Guilherme',
#   53,
#   'Caixa de Som',
#   47.21,
#   8345.5,
#   'PA',
#   'Belém',
#   datetime.date(2025, 7, 12)),
#  (100,
#   15,
#   'Bianca',
#   10,
#   'Notebook',
#   85.88,
#   5443.66,
#   'RO',
#   'Porto Velho',
#   datetime.date(2023, 2, 18))]

# %%
spark = SparkSession.builder.appName(name="ecommerce").getOrCreate()
# Out:
# 25/09/03 20:56:57 WARN Utils: Your hostname, ademir resolves to a loopback address: 127.0.1.1; using 192.168.15.11 instead (on interface eno1)
# 25/09/03 20:56:57 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/09/03 20:57:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Definindo o schema

schema = StructType([
    StructField("nrPedido", IntegerType(), True),
    StructField("codCliente", IntegerType(), True),
    StructField("cliente", StringType(), True),
    StructField("qtd", IntegerType(), True),
    StructField("produto", StringType(), True),
    StructField("custo", FloatType(), True),
    StructField("valorVenda", FloatType(), True),
    StructField("uf", StringType(), True),
    StructField("cidade", StringType(), True),
    StructField("data", DateType(), True),
    
])

# %%
# Gerando dados fictícios de clientes para o DF
dados_vendas = gerardados(nome_cliente, estado_cidade, produtos)

# %%
# Atribuindo os dados ao df
df = spark.createDataFrame(dados_vendas, schema)

# %%
# Prévia dos dados.
df.limit(10).show(truncate = False)
# Out:
# +--------+----------+--------+---+----------+-----+----------+---+--------------------+----------+
# |nrPedido|codCliente|cliente |qtd|produto   |custo|valorVenda|uf |cidade              |data      |
# +--------+----------+--------+---+----------+-----+----------+---+--------------------+----------+
# |1       |77        |Talita  |49 |Monitor   |37.97|8683.55   |RO |Ji-Paraná           |2025-04-27|
# |2       |27        |Daniel  |94 |Smartphone|55.38|8807.83   |GO |Aparecida de Goiânia|2023-12-19|
# |3       |10        |Elisa   |42 |Smartwatch|22.75|6143.51   |RN |Parnamirim          |2021-08-20|
# |4       |75        |Samuel  |100|Impressora|13.86|6853.12   |BA |Salvador            |2021-11-01|
# |5       |37        |Emerson |28 |Impressora|43.61|7168.9    |DF |Brasília            |2022-02-25|
# |6       |7         |Elisa   |92 |Câmera    |35.62|5298.31   |AL |Palmeira dos Índios |2021-05-03|
# |7       |9         |Alice   |8  |Monitor   |90.78|2302.48   |MS |Dourados            |2023-07-17|
# |8       |29        |Giovanna|26 |Impressora|63.77|4980.99   |DF |Brasília            |2021-06-19|
# |9       |98        |Fernanda|48 |Roteador  |60.37|18071.46  |SC |Blumenau            |2022-11-17|
# |10      |6         |Henrique|29 |Câmera    |51.71|2693.01   |SE |Lagarto             |2024-01-23|
# +--------+----------+--------+---+----------+-----+----------+---+--------------------+----------+

# %%
# Identificando o schema
df.printSchema()
# Out:
# root
#  |-- nrPedido: integer (nullable = true)
#  |-- codCliente: integer (nullable = true)
#  |-- cliente: string (nullable = true)
#  |-- qtd: integer (nullable = true)
#  |-- produto: string (nullable = true)
#  |-- custo: float (nullable = true)
#  |-- valorVenda: float (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- cidade: string (nullable = true)
#  |-- data: date (nullable = true)

# %%
# Identificando o número total de linhas
df.count()
# Out:
# 100

# %%
# Estados que tiveram apenas uma venda, e qual produto foi vendido
df.filter(df.qtd == 1).select(df.uf, df.produto).show()
# Out:
# +---+--------+
# | uf| produto|
# +---+--------+
# | TO|Roteador|
# +---+--------+

# %%
df.select(F.round(F.avg(F.col("valorVenda")), 2).alias("MediaVendas")).show()
# Out:
# +-----------+
# |MediaVendas|
# +-----------+
# |   10671.72|
# +-----------+

# %%
## Forma alternativa para obter a média (complexa)

# Média de vendas
df_media_vendas = df.agg({"valorVenda": "avg"})

# Imprimindo e renomeando a coluna com o cálculo médio para melhor compreensão.
df_media_vendas = df_media_vendas.withColumnRenamed("avg(valorVenda)", "MediaVendas")

df_media_vendas.select(F.round(df_media_vendas.MediaVendas,2).alias("MediaVendas")).show()
# Out:
# 25/09/03 20:57:18 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# +-----------+
# |MediaVendas|
# +-----------+
# |   10671.72|
# +-----------+

# %%
# Produto mais vendido
#df.select(F.max("qtd")).show()
#df.orderBy(F.desc("qtd")).select("produto", "qtd").limit(1).show()
df_qtd_max = df.groupBy("produto").max("qtd").alias("total")
df_qtd_max.orderBy(F.desc("max(qtd)")).limit(3).show()
# Out:
# +----------+--------+
# |   produto|max(qtd)|
# +----------+--------+
# |Impressora|     100|
# |Smartwatch|      99|
# |  Notebook|      99|
# +----------+--------+

# %%
df.groupBy("produto").sum("valorVenda").show()
# Out:
# +--------------+------------------+
# |       produto|   sum(valorVenda)|
# +--------------+------------------+
# |  Caixa de Som|  66820.8193359375|
# |    Smartwatch| 67089.51141357422|
# |      Roteador| 99902.24142456055|
# |        Câmera| 96675.42163085938|
# |      Notebook| 81784.99951171875|
# |        Tablet|117826.44055175781|
# |    Smartphone| 91042.81039428711|
# |       Monitor|146432.29887390137|
# |    Impressora|131768.97814941406|
# |Fone de Ouvido|167828.67810058594|
# +--------------+------------------+

# %%
df2 = (
    df.groupBy("Produto")
    .sum("valorVenda")
    .show(n=10)     
)
# Out:
# +--------------+------------------+
# |       Produto|   sum(valorVenda)|
# +--------------+------------------+
# |  Caixa de Som|  66820.8193359375|
# |    Smartwatch| 67089.51141357422|
# |      Roteador| 99902.24142456055|
# |        Câmera| 96675.42163085938|
# |      Notebook| 81784.99951171875|
# |        Tablet|117826.44055175781|
# |    Smartphone| 91042.81039428711|
# |       Monitor|146432.29887390137|
# |    Impressora|131768.97814941406|
# |Fone de Ouvido|167828.67810058594|
# +--------------+------------------+

# %%
dfduplicados = (
    df.groupBy(df.produto)
    .count()
    .filter(col("count") > 1)
    .sort("count", ascending=False)
    .limit(10)
    .show()
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 dfduplicados = (
#       2     df.groupBy(df.produto)
#       3     .count()
# ----> 4     .filter(col("count") > 1)
#       5     .sort("count", ascending=False)
#       6     .limit(10)
#       7     .show()
#       8 )
#
# NameError: name 'col' is not defined

# %%
# Dropando dados duplicados
df.dropDuplicates().show(10)

# %%
# 5. *Custo Médio por Estado:  - Qual é o custo médio dos produtos vendidos em cada estado?
df.select(round(F.avg(col("custo")),2).alias("custoMedio")).show()

# %%
# 6. *Total de Vendas por Cliente: Qual é o total de vendas (valor de venda) por cliente?

df_total_por_clientes = (
    df
    .groupBy("cliente")
    .agg(F.round(F.sum("valorVenda"),2).alias("totalPorCliente"))
    .withColumnRenamed("sum(valorVenda)", "totalPorCliente")
    .show(10)
)

# %%
# 7. Data Mais Recente e Mais Antiga: Qual é a data mais recente e a mais antiga registrada nos dados?
df_antigo_recente = (
    df
    .select(min(df.data)
    .alias("antigo"),
    max(df.data)
    .alias("recente"))
    .show()
)

# %%
# 8. *Quantidade de Vendas por Dia: Quantas vendas ocorreram em cada dia?
df_total_diario = (
    df
    .groupBy(date_format("data", "dd/MM/yyyy").alias("data"))
    .agg(round(sum("valorVenda"),2)
    .alias("TotalVendaDiaria"))
    .limit(10)
    .show()
)

# %%
# 9. *Custo Médio e Valor de Venda Médio por Produto: Qual é o custo médio e o valor de venda médio para cada produto?
df_custoMedio_vendaMedia = (
    df.groupBy("produto")    
    .agg(round(avg("custo"),2)    
    .alias("custoMedio"),
    round(avg("valorVenda"))
    .alias("receitaMedia"))
    .limit(10)
    .show()
)

# %%
# 10. *Porcentagem de Lucro: Qual é a porcentagem média de lucro (baseado no custo e valor de venda) em todas as vendas?
custo_venda = df.withColumn("custoTotal", (df.qtd * df.custo))
custo_venda.show()

# %%
lucro_percentual = custo_venda.withColumn("lucroPercentual", round((custo_venda.custoTotal * custo_venda.valorVenda) / 100))
lucro_percentual.show()

# %% [markdown]
# # Trabalhando com datas

# %%
#11) Data Mais Recente e Mais Antiga: Objetivo: Descobrir qual é a data mais recente e a mais antiga registrada nos dados.

data_recente_antiga = (
    df.select(
        F.max(date_format(df.data, "dd/MM/yyyy"))
        .alias("dataAntiga"), 
        F.min(date_format("data", "dd/MM/yyyy"))
        .alias("dataRecente"))
)

data_recente_antiga.show()

# %%
df.select(F.min(df.data).alias("dataAntiga")).show()

# %%
# 12) Quantidade de Vendas por Dia. Objetivo: Contar quantas vendas ocorreram em cada dia.
#df.groupBy("data").agg(sum("qtd").alias("qtdDia")).show()
df_qtdDia = (
    df.groupBy("data")
    .agg(sum("qtd").alias("qtdDia"))    
    .sort("data")
)

df_qtdDia.show()

# %% [markdown]
# ### Adicionar Coluna com Ano e Mês. Objetivo: Adicionar uma coluna que contenha apenas o ano e o mês da data da venda.

# %%
# 13) Adicionar Coluna com Ano e Mês Objetivo: Adicionar uma coluna que contenha apenas o ano e o mês da data da venda.
df_ano_mes = df.withColumn("ano_mes", date_format(df.data, "yyyy-MM"))
df_ano_mes.show()

# %%
# 14) Filtrar Vendas de um Mês Específico. Objetivo: Filtrar todas as vendas que ocorreram no mês de julho de 2024.
df.filter((year(col("data")) == 2024) & (month(col("data")) == 6)).show(10)

# %% [markdown]
# #### Adicionar Coluna com Dia da Semana. Objetivo: Adicionar uma coluna que mostre o dia da semana para cada data de venda.

# %%
# 15) Adicionar Coluna com Dia da Semana. Objetivo: Adicionar uma coluna que mostre o dia da semana para cada data de venda.
df_dia_semana = df.withColumn("dia_semana", date_format(df.data, "EEEE"))
df_dia_semana.show()

# %%
# 16) Determinar o Dia da Semana com Mais Vendas
# Objetivo: Descobrir qual dia da semana teve o maior número de vendas totais (soma das quantidades vendidas).

df_dia_semana_total_qtd = (
    df_dia_semana
    .groupBy("dia_semana")
    .agg(sum("qtd").alias("qtd"))
    .sort("qtd", ascending=False)    
)
df_dia_semana_total_qtd.show()

# %%
# 17) Calcular a Média de Vendas por Mês:
# Objetivo: Calcular a média da quantidade de vendas realizadas em cada mês.

df_media_vendas_mes = (
    df.groupBy(month("data")
               .alias("MesCorrespondente"))
    .agg(round(F.avg("valorVenda"),2)
         .alias("TotalPorMes"))
)
df_media_vendas_mes.show()

# %%
#Exercício 20: Calcular a Média de Vendas por Produto em Cada Ano 
# Objetivo: Calcular a média de vendas realizadas para cada produto em cada ano. Utilize uma estrutura de repetição para iterar sobre os anos e calcular a média das vendas.

ano_venda = df.select(year(df.data).alias("ano")).distinct().sort("data").collect()

# %%
print(ano_venda)

# %%
df_weekend = df.withColumn("dia_semana", date_format(df.data, "EEEE"))
df_weekend.filter((df_weekend.dia_semana ==  "Saturday") | (df_weekend.dia_semana == "Sunday")).show()

# %%
df.filter(F.col("uf") == "SP").limit(3).show()

# %% [markdown]
#
#
#
#
#
#
#
#
#
#
# 26. Identificar Vendas com Prejuízo
#    - Liste todas as vendas onde o custo (`custo * qtd`) foi maior que o valor de venda (`valorVenda * qtd`).
#
# 27. Clientes que Compraram Apenas Uma Vez
#    - Encontre os clientes que realizaram apenas um pedido no e-commerce.
#
# 28. Produto Mais Vendido em Cada Estado
#    - Descubra qual produto teve a maior quantidade vendida em cada estado (`uf`).
#
# 29. Crescimento Mensal do Faturamento
#    - Calcule o crescimento percentual do faturamento mês a mês.
#
# 30. Cliente com Maior Ticket Médio
#    - Encontre o cliente que possui o maior ticket médio, considerando apenas aqueles que realizaram pelo menos 5 compras.

# %%
#21. Clientes com Mais Compras  
#   Identifique os 5 clientes que mais realizaram compras, considerando a quantidade total de itens (`qtd`). 

df.orderBy(F.col("qtd").desc()).limit(5).show()

# %%
#22. Estados com Maior Receita  
# Liste os estados (`uf`) ordenados pela maior receita total (`valorVenda`). 

df.orderBy(F.col("valorVenda").desc()).limit(10).show()

# %%
# 23. Produtos com Maior Faturamento  
#   - Quais são os 5 produtos que geraram o maior faturamento total (`valorVenda * qtd`)?  

df_faturamento = df.withColumn("total", df.valorVenda * df.qtd)

# %%
#df_faturamento.groupBy(df_faturamento.produto).agg(round(F.sum("total"),2).alias("total")).show()
df_faturamento.groupBy("produto") \
    .agg(F.round(F.sum("total"), 2).alias("total")) \
    .orderBy(F.desc("total")) \
    .show()

# %%
#24. Ticket Médio por Cliente  
#   - Calcule o ticket médio por cliente, considerando a soma do `valorVenda` dividida pelo número de pedidos.  

df_ticket_medio = df.groupBy("codCliente").agg((F.sum("valorVenda") / F.sum("qtd")).alias("media"))
df_ticket_medio.show()

# %%
#25. Comparação de Faturamento por Cidade  
#   - Para cada estado, encontre a cidade com o maior faturamento total.  
df.filter(F.col("uf"))
