# %%
# Importações básicas
import os
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql import DataFrame
from pyspark.sql import functions as F
from pyspark.sql.functions import *
from pyspark.sql.types import StructType,StructField, StringType, IntegerType, FloatType, DateType
from datetime import date, timedelta, datetime
import random
import calendar
from dateutil.relativedelta import relativedelta
import locale
import logging

# %%
logging.basicConfig(level=logging.INFO, filename="teste.log")

# %%
# Lista de clientes
nome_cliente = [
    "Ana", "João", "Maria", "Pedro", "Júlia", "Lucas", "Larissa", "Gabriel", "Beatriz", "Felipe", "Clara",
    "Daniel", "Laura", "Rafael", "Mariana", "Gustavo", "Luísa", "Henrique", "Sofia", "Matheus", "Isabella",
    "Bruno", "Alice", "Thiago", "Helena", "Rodrigo", "Giovanna", "Eduardo", "Rafaela", "Leonardo", "Nicole",
    "Caio", "Vitória", "André", "Fernanda", "Diego", "Yasmin", "Guilherme", "Letícia", "Vinícius", "Camila",
    "Igor", "Valentina", "Otávio", "Bianca", "Enzo", "Lorena", "Alex", "Elisa", "Murilo", "Vitória", "Samuel",
    "Gabriela", "Arthur", "Evelyn", "Miguel", "Marina", "Renan", "Tainá", "Jorge", "Juliana", "Samuel",
    "Melissa", "Raul", "Camila", "Levi", "Carolina", "Nathan", "Cecília", "Lucas", "Amanda", "Benjamin",
    "Lívia", "Heitor", "Bruna", "Davi", "Talita", "Theo", "Maíra", "Tomás", "Ana Clara", "Vicente", "Isadora",
    "Alexandre", "Sabrina", "Emerson", "Thaís", "Renata", "Otávio", "Priscila", "Eduardo", "Natália", "Jonas",
    "Aline", "Cristiano", "Patrícia", "Vicente", "Elisa"
]

# Lista de estados e cidades
estado_cidade = {
    "AC": ["Rio Branco", "Cruzeiro do Sul", "Sena Madureira"],
    "AL": ["Maceió", "Arapiraca", "Palmeira dos Índios"],
    "AP": ["Macapá", "Santana", "Laranjal do Jari"],
    "AM": ["Manaus", "Parintins", "Itacoatiara"],
    "BA": ["Salvador", "Feira de Santana", "Vitória da Conquista"],
    "CE": ["Fortaleza", "Caucaia", "Juazeiro do Norte"],
    "DF": ["Brasília"],
    "ES": ["Vitória", "Vila Velha", "Serra"],
    "GO": ["Goiânia", "Anápolis", "Aparecida de Goiânia"],
    "MA": ["São Luís", "Imperatriz", "Timon"],
    "MT": ["Cuiabá", "Várzea Grande", "Rondonópolis"],
    "MS": ["Campo Grande", "Dourados", "Três Lagoas"],
    "MG": ["Belo Horizonte", "Uberlândia", "Contagem"],
    "PA": ["Belém", "Ananindeua", "Santarém"],
    "PB": ["João Pessoa", "Campina Grande", "Santa Rita"],
    "PR": ["Curitiba", "Londrina", "Maringá"],
    "PE": ["Recife", "Jaboatão dos Guararapes", "Olinda"],
    "PI": ["Teresina", "Parnaíba", "Picos"],
    "RJ": ["Rio de Janeiro", "Niterói", "Duque de Caxias"],
    "RN": ["Natal", "Mossoró", "Parnamirim"],
    "RS": ["Porto Alegre", "Caxias do Sul", "Pelotas"],
    "RO": ["Porto Velho", "Ji-Paraná", "Ariquemes"],
    "RR": ["Boa Vista", "Rorainópolis", "Caracaraí"],
    "SC": ["Florianópolis", "Joinville", "Blumenau"],
    "SP": ["São Paulo", "Campinas", "São Bernardo do Campo"],
    "SE": ["Aracaju", "Nossa Senhora do Socorro", "Lagarto"],
    "TO": ["Palmas", "Araguaína", "Gurupi"]
}

# Lista de produtos eletrônicos
produtos = ["Smartphone", "Notebook", "Tablet", "Monitor", "Fone de Ouvido", "Smartwatch", "Câmera", "Impressora", "Caixa de Som", "Roteador"]

# %%
print(len(nome_cliente))
print(len(estado_cidade))
print(len(produtos))
# Out:
# 98
# 27
# 10

# %%
def gerardados(nome_cliente, estado_cidade, produtos):

    vendas = []
        
# Gera dados para número do pedido e código do cliente
    for dados in range(1,101):

        nrpedido = dados
        codcliente = random.randint(1, 100)  
        cliente = random.choice(nome_cliente)      
        qtd =  random.randint(1, 100)
        produto = random.choice(produtos)
        custo = float(random.uniform(1, 100))
        valor_venda = float(qtd * (custo * random.uniform(1.5, 8.0))) # Escolhe uma margem de lucro entre 1.5 e 8.0.
        data_inicial = date.today() - relativedelta(years=5)  # Captura a data atual e subtrai 5 anos.
        data_final = date.today()
        # Listando o período de data inicial e data final
        datas = [data_inicial + timedelta(days=i) for i in range((data_final - data_inicial).days + 1)]
        data = random.choice(datas)

        uf = random.choice(list(estado_cidade.keys()))
        cidade = random.choice(estado_cidade[uf])
        vendas.append((nrpedido, codcliente, cliente, qtd, produto, custo, valor_venda, uf, cidade, data))

    return vendas

# %%
gerardados(nome_cliente, estado_cidade, produtos)
# Out:
# [(1,
#   2,
#   'Nathan',
#   6,
#   'Câmera',
#   6.222276687227647,
#   125.07258382302497,
#   'MT',
#   'Cuiabá',
#   datetime.date(2022, 1, 28)),
#  (2,
#   45,
#   'Sabrina',
#   92,
#   'Notebook',
#   85.8255189741394,
#   46251.361990629615,
#   'AC',
#   'Rio Branco',
#   datetime.date(2025, 1, 23)),
#  (3,
#   31,
#   'Gabriel',
#   33,
#   'Smartphone',
#   64.94247162777677,
#   9220.40205359978,
#   'PA',
#   'Santarém',
#   datetime.date(2021, 9, 28)),
#  (4,
#   44,
#   'Murilo',
#   5,
#   'Smartphone',
#   90.59273629151268,
#   901.3767491277486,
#   'TO',
#   'Araguaína',
#   datetime.date(2023, 5, 13)),
#  (5,
#   61,
#   'Diego',
#   67,
#   'Notebook',
#   43.80264758415228,
#   10602.328676737581,
#   'TO',
#   'Palmas',
#   datetime.date(2022, 5, 1)),
#  (6,
#   73,
#   'Bruno',
#   12,
#   'Notebook',
#   98.65327113377086,
#   8358.826122853321,
#   'PI',
#   'Parnaíba',
#   datetime.date(2020, 8, 29)),
#  (7,
#   71,
#   'Maíra',
#   25,
#   'Caixa de Som',
#   79.92099386309529,
#   12648.249210415013,
#   'GO',
#   'Anápolis',
#   datetime.date(2021, 7, 31)),
#  (8,
#   86,
#   'Alice',
#   52,
#   'Impressora',
#   12.346573844032237,
#   1718.988480414876,
#   'MS',
#   'Três Lagoas',
#   datetime.date(2021, 7, 14)),
#  (9,
#   1,
#   'Laura',
#   62,
#   'Monitor',
#   83.15737268361733,
#   11431.67287428913,
#   'AL',
#   'Arapiraca',
#   datetime.date(2020, 4, 4)),
#  (10,
#   95,
#   'Otávio',
#   5,
#   'Roteador',
#   30.095847972949286,
#   585.1427983020792,
#   'SC',
#   'Florianópolis',
#   datetime.date(2023, 9, 12)),
#  (11,
#   24,
#   'Vinícius',
#   55,
#   'Fone de Ouvido',
#   66.17511293182919,
#   13477.22561254064,
#   'PB',
#   'Campina Grande',
#   datetime.date(2023, 4, 11)),
#  (12,
#   35,
#   'Davi',
#   58,
#   'Impressora',
#   92.77137152895358,
#   39850.09126348064,
#   'SP',
#   'Campinas',
#   datetime.date(2023, 12, 22)),
#  (13,
#   43,
#   'Caio',
#   20,
#   'Smartphone',
#   56.49796799153273,
#   3583.767468582228,
#   'RO',
#   'Porto Velho',
#   datetime.date(2024, 4, 24)),
#  (14,
#   75,
#   'Felipe',
#   63,
#   'Smartwatch',
#   98.03437450724094,
#   48194.75880228324,
#   'DF',
#   'Brasília',
#   datetime.date(2024, 11, 15)),
#  (15,
#   15,
#   'Daniel',
#   48,
#   'Notebook',
#   19.586411450857366,
#   2099.2063577376657,
#   'AC',
#   'Cruzeiro do Sul',
#   datetime.date(2021, 7, 2)),
#  (16,
#   43,
#   'Thiago',
#   22,
#   'Tablet',
#   82.83618902039106,
#   8784.785746817577,
#   'MA',
#   'São Luís',
#   datetime.date(2022, 11, 8)),
#  (17,
#   69,
#   'Yasmin',
#   36,
#   'Impressora',
#   48.37248092198678,
#   3041.5651502345254,
#   'RN',
#   'Natal',
#   datetime.date(2024, 10, 2)),
#  (18,
#   68,
#   'Natália',
#   49,
#   'Impressora',
#   32.29041202298983,
#   11787.405413657403,
#   'AM',
#   'Manaus',
#   datetime.date(2023, 2, 6)),
#  (19,
#   83,
#   'Marina',
#   26,
#   'Caixa de Som',
#   60.86251786701957,
#   2394.344921750369,
#   'CE',
#   'Caucaia',
#   datetime.date(2023, 10, 1)),
#  (20,
#   80,
#   'Henrique',
#   9,
#   'Smartwatch',
#   96.87089750201118,
#   4862.763255828094,
#   'SE',
#   'Lagarto',
#   datetime.date(2021, 9, 17)),
#  (21,
#   32,
#   'Gabriel',
#   24,
#   'Impressora',
#   2.774898784147853,
#   276.73749613154354,
#   'RO',
#   'Ji-Paraná',
#   datetime.date(2020, 6, 12)),
#  (22,
#   45,
#   'Ana Clara',
#   14,
#   'Smartwatch',
#   41.873853142206116,
#   2589.983266491485,
#   'CE',
#   'Juazeiro do Norte',
#   datetime.date(2021, 10, 26)),
#  (23,
#   55,
#   'Levi',
#   65,
#   'Câmera',
#   32.19065820147303,
#   6484.688913134197,
#   'AL',
#   'Palmeira dos Índios',
#   datetime.date(2021, 11, 11)),
#  (24,
#   8,
#   'Renan',
#   17,
#   'Notebook',
#   77.64349165272253,
#   6055.097048843207,
#   'ES',
#   'Vitória',
#   datetime.date(2021, 10, 9)),
#  (25,
#   32,
#   'Raul',
#   39,
#   'Smartphone',
#   82.6860150023014,
#   10695.439309407759,
#   'MG',
#   'Contagem',
#   datetime.date(2021, 9, 8)),
#  (26,
#   97,
#   'Jonas',
#   53,
#   'Caixa de Som',
#   21.042347451534592,
#   4681.801713897825,
#   'SE',
#   'Nossa Senhora do Socorro',
#   datetime.date(2022, 12, 18)),
#  (27,
#   22,
#   'Júlia',
#   45,
#   'Roteador',
#   98.73015860181971,
#   21641.530934384817,
#   'PR',
#   'Londrina',
#   datetime.date(2023, 6, 6)),
#  (28,
#   9,
#   'Thiago',
#   50,
#   'Impressora',
#   1.4681611720709369,
#   320.7840383429879,
#   'MG',
#   'Belo Horizonte',
#   datetime.date(2021, 1, 12)),
#  (29,
#   69,
#   'Camila',
#   36,
#   'Notebook',
#   24.69104484039791,
#   3155.9378692239898,
#   'MG',
#   'Contagem',
#   datetime.date(2024, 3, 29)),
#  (30,
#   10,
#   'Mariana',
#   65,
#   'Caixa de Som',
#   59.00933232523319,
#   18443.05185910746,
#   'AC',
#   'Rio Branco',
#   datetime.date(2021, 11, 16)),
#  (31,
#   97,
#   'Rafael',
#   87,
#   'Fone de Ouvido',
#   8.18744953667714,
#   5655.561798837292,
#   'AC',
#   'Rio Branco',
#   datetime.date(2024, 9, 29)),
#  (32,
#   96,
#   'Maíra',
#   43,
#   'Fone de Ouvido',
#   47.2245663037854,
#   3237.849020166143,
#   'TO',
#   'Araguaína',
#   datetime.date(2022, 10, 13)),
#  (33,
#   33,
#   'Larissa',
#   46,
#   'Roteador',
#   10.684885268599745,
#   2049.429006574145,
#   'BA',
#   'Vitória da Conquista',
#   datetime.date(2021, 5, 18)),
#  (34,
#   100,
#   'Gustavo',
#   68,
#   'Impressora',
#   75.80327338402846,
#   31058.782502896578,
#   'ES',
#   'Serra',
#   datetime.date(2024, 7, 30)),
#  (35,
#   24,
#   'Maíra',
#   10,
#   'Smartphone',
#   98.908104330482,
#   2252.6771151577705,
#   'SP',
#   'São Bernardo do Campo',
#   datetime.date(2020, 5, 2)),
#  (36,
#   58,
#   'Maíra',
#   41,
#   'Fone de Ouvido',
#   2.9981803854878257,
#   581.7145455324315,
#   'RN',
#   'Natal',
#   datetime.date(2025, 2, 10)),
#  (37,
#   90,
#   'Vinícius',
#   80,
#   'Caixa de Som',
#   74.58042062438123,
#   30848.319941894108,
#   'SC',
#   'Blumenau',
#   datetime.date(2024, 9, 7)),
#  (38,
#   2,
#   'Otávio',
#   36,
#   'Tablet',
#   57.51679630464643,
#   7813.751853382529,
#   'MA',
#   'São Luís',
#   datetime.date(2021, 4, 29)),
#  (39,
#   51,
#   'Henrique',
#   85,
#   'Caixa de Som',
#   59.41974335106366,
#   10679.092019278203,
#   'PB',
#   'Campina Grande',
#   datetime.date(2020, 6, 12)),
#  (40,
#   74,
#   'Gustavo',
#   29,
#   'Câmera',
#   11.239027234901352,
#   621.2656030363255,
#   'MG',
#   'Uberlândia',
#   datetime.date(2023, 8, 8)),
#  (41,
#   82,
#   'Henrique',
#   64,
#   'Smartphone',
#   70.36948796032473,
#   8793.26423099952,
#   'BA',
#   'Feira de Santana',
#   datetime.date(2021, 9, 5)),
#  (42,
#   26,
#   'Bruno',
#   62,
#   'Fone de Ouvido',
#   59.41233572788149,
#   27511.223559832684,
#   'MG',
#   'Contagem',
#   datetime.date(2021, 10, 15)),
#  (43,
#   16,
#   'Rafaela',
#   25,
#   'Roteador',
#   90.76428453769941,
#   7607.167162997534,
#   'ES',
#   'Serra',
#   datetime.date(2022, 1, 10)),
#  (44,
#   54,
#   'Fernanda',
#   42,
#   'Notebook',
#   21.671883427042978,
#   4834.368322668737,
#   'RJ',
#   'Niterói',
#   datetime.date(2020, 12, 5)),
#  (45,
#   84,
#   'Aline',
#   77,
#   'Smartwatch',
#   21.09921255703297,
#   12054.313485391158,
#   'SE',
#   'Lagarto',
#   datetime.date(2022, 7, 4)),
#  (46,
#   2,
#   'Igor',
#   24,
#   'Tablet',
#   59.70959134754816,
#   3172.264422887916,
#   'RN',
#   'Parnamirim',
#   datetime.date(2022, 6, 25)),
#  (47,
#   38,
#   'Vicente',
#   50,
#   'Impressora',
#   37.08858681978493,
#   5758.406001401985,
#   'AL',
#   'Arapiraca',
#   datetime.date(2024, 12, 24)),
#  (48,
#   20,
#   'Levi',
#   81,
#   'Impressora',
#   51.805377747166986,
#   29527.839946806605,
#   'RN',
#   'Parnamirim',
#   datetime.date(2020, 12, 20)),
#  (49,
#   21,
#   'Bruno',
#   55,
#   'Smartphone',
#   30.373768651193927,
#   12943.441936817177,
#   'MA',
#   'Timon',
#   datetime.date(2024, 2, 21)),
#  (50,
#   96,
#   'Beatriz',
#   19,
#   'Smartphone',
#   15.900063928971099,
#   553.6007578697414,
#   'SE',
#   'Aracaju',
#   datetime.date(2020, 10, 17)),
#  (51,
#   76,
#   'Samuel',
#   72,
#   'Caixa de Som',
#   5.0749711032568054,
#   2732.291621156433,
#   'PI',
#   'Teresina',
#   datetime.date(2022, 9, 18)),
#  (52,
#   8,
#   'Alex',
#   7,
#   'Smartwatch',
#   76.40603645248908,
#   1031.8201905577744,
#   'RO',
#   'Ariquemes',
#   datetime.date(2023, 3, 27)),
#  (53,
#   11,
#   'Aline',
#   95,
#   'Notebook',
#   93.32369543546407,
#   50331.894114704526,
#   'MA',
#   'Timon',
#   datetime.date(2020, 5, 15)),
#  (54,
#   8,
#   'Eduardo',
#   56,
#   'Câmera',
#   61.899063065175845,
#   12700.490956586365,
#   'AL',
#   'Arapiraca',
#   datetime.date(2022, 5, 23)),
#  (55,
#   14,
#   'Thaís',
#   70,
#   'Monitor',
#   51.74234520692983,
#   20196.30333255326,
#   'DF',
#   'Brasília',
#   datetime.date(2025, 1, 8)),
#  (56,
#   64,
#   'Letícia',
#   98,
#   'Caixa de Som',
#   29.023693704439097,
#   9390.53961319056,
#   'SP',
#   'São Bernardo do Campo',
#   datetime.date(2023, 4, 12)),
#  (57,
#   4,
#   'Lucas',
#   35,
#   'Smartwatch',
#   27.553365740121503,
#   3871.916635416332,
#   'MG',
#   'Uberlândia',
#   datetime.date(2023, 7, 2)),
#  (58,
#   12,
#   'Heitor',
#   22,
#   'Roteador',
#   68.62359742782893,
#   5259.992949952776,
#   'AC',
#   'Rio Branco',
#   datetime.date(2024, 3, 31)),
#  (59,
#   22,
#   'Pedro',
#   20,
#   'Notebook',
#   99.80884490985103,
#   4089.9143116830305,
#   'RR',
#   'Caracaraí',
#   datetime.date(2024, 5, 1)),
#  (60,
#   36,
#   'Thaís',
#   62,
#   'Câmera',
#   14.432383731456326,
#   4979.153911884847,
#   'TO',
#   'Gurupi',
#   datetime.date(2022, 10, 16)),
#  (61,
#   95,
#   'Beatriz',
#   16,
#   'Monitor',
#   84.37951051457831,
#   7962.6735912374825,
#   'AC',
#   'Rio Branco',
#   datetime.date(2023, 2, 26)),
#  (62,
#   45,
#   'Camila',
#   33,
#   'Câmera',
#   97.95633634375118,
#   8860.179628538683,
#   'AC',
#   'Rio Branco',
#   datetime.date(2023, 6, 13)),
#  (63,
#   56,
#   'Maíra',
#   74,
#   'Tablet',
#   56.26020632146303,
#   20224.72629641773,
#   'SP',
#   'Campinas',
#   datetime.date(2021, 11, 18)),
#  (64,
#   1,
#   'Heitor',
#   60,
#   'Monitor',
#   58.95003827541519,
#   22264.25715300301,
#   'RN',
#   'Natal',
#   datetime.date(2024, 4, 13)),
#  (65,
#   78,
#   'Felipe',
#   48,
#   'Monitor',
#   90.95519146516446,
#   10223.93030225934,
#   'PB',
#   'João Pessoa',
#   datetime.date(2022, 4, 26)),
#  (66,
#   86,
#   'Igor',
#   54,
#   'Câmera',
#   37.379616198486374,
#   8245.960536195202,
#   'RN',
#   'Mossoró',
#   datetime.date(2022, 2, 27)),
#  (67,
#   76,
#   'Miguel',
#   30,
#   'Notebook',
#   44.73918141722054,
#   2161.4415725705435,
#   'RS',
#   'Caxias do Sul',
#   datetime.date(2022, 10, 6)),
#  (68,
#   22,
#   'Aline',
#   64,
#   'Smartwatch',
#   40.286373180354474,
#   10103.661587433437,
#   'BA',
#   'Vitória da Conquista',
#   datetime.date(2024, 3, 20)),
#  (69,
#   52,
#   'Marina',
#   64,
#   'Impressora',
#   22.82886632123422,
#   5734.1298397359415,
#   'PE',
#   'Olinda',
#   datetime.date(2024, 5, 7)),
#  (70,
#   3,
#   'Lucas',
#   62,
#   'Smartwatch',
#   75.39758633973811,
#   33104.69971228355,
#   'RR',
#   'Rorainópolis',
#   datetime.date(2021, 1, 24)),
#  (71,
#   52,
#   'André',
#   88,
#   'Smartphone',
#   87.54555714813554,
#   28167.995299101567,
#   'PR',
#   'Londrina',
#   datetime.date(2021, 10, 6)),
#  (72,
#   51,
#   'Otávio',
#   24,
#   'Câmera',
#   16.065583135143186,
#   581.493966139035,
#   'TO',
#   'Gurupi',
#   datetime.date(2024, 8, 7)),
#  (73,
#   2,
#   'Vicente',
#   97,
#   'Notebook',
#   88.77871207955003,
#   38352.763649315995,
#   'SC',
#   'Blumenau',
#   datetime.date(2023, 6, 27)),
#  (74,
#   10,
#   'Gustavo',
#   24,
#   'Caixa de Som',
#   95.75989821202461,
#   5585.523699345989,
#   'PR',
#   'Maringá',
#   datetime.date(2023, 11, 15)),
#  (75,
#   65,
#   'Alice',
#   44,
#   'Impressora',
#   51.741443910565636,
#   13712.277208897176,
#   'BA',
#   'Vitória da Conquista',
#   datetime.date(2023, 9, 28)),
#  (76,
#   10,
#   'Leonardo',
#   46,
#   'Câmera',
#   55.684140644626815,
#   9991.009220876458,
#   'RJ',
#   'Niterói',
#   datetime.date(2022, 2, 23)),
#  (77,
#   23,
#   'Elisa',
#   51,
#   'Smartwatch',
#   94.9544900049441,
#   20058.52025991027,
#   'PB',
#   'Santa Rita',
#   datetime.date(2020, 11, 19)),
#  (78,
#   48,
#   'Diego',
#   50,
#   'Smartwatch',
#   13.222086780838262,
#   2814.636296668202,
#   'RR',
#   'Caracaraí',
#   datetime.date(2021, 6, 24)),
#  (79,
#   6,
#   'João',
#   91,
#   'Câmera',
#   63.848353859624225,
#   28839.28756943709,
#   'MG',
#   'Uberlândia',
#   datetime.date(2024, 10, 1)),
#  (80,
#   80,
#   'Ana',
#   21,
#   'Câmera',
#   14.99233833608167,
#   1225.4714556906238,
#   'AP',
#   'Macapá',
#   datetime.date(2020, 9, 29)),
#  (81,
#   89,
#   'Juliana',
#   13,
#   'Câmera',
#   51.51662315562597,
#   1387.001245469858,
#   'PA',
#   'Belém',
#   datetime.date(2020, 6, 14)),
#  (82,
#   89,
#   'Alexandre',
#   65,
#   'Caixa de Som',
#   66.83572695492377,
#   29019.918373568136,
#   'PE',
#   'Olinda',
#   datetime.date(2020, 6, 17)),
#  (83,
#   98,
#   'Elisa',
#   64,
#   'Fone de Ouvido',
#   6.752735242147272,
#   1778.6214687187226,
#   'AL',
#   'Arapiraca',
#   datetime.date(2023, 1, 3)),
#  (84,
#   92,
#   'Alice',
#   4,
#   'Smartphone',
#   79.99861530893222,
#   2558.290918715271,
#   'AC',
#   'Cruzeiro do Sul',
#   datetime.date(2023, 10, 23)),
#  (85,
#   24,
#   'Bianca',
#   49,
#   'Notebook',
#   2.151197914776303,
#   505.54486015881946,
#   'RO',
#   'Ji-Paraná',
#   datetime.date(2022, 6, 6)),
#  (86,
#   90,
#   'Maria',
#   14,
#   'Roteador',
#   59.20947968320992,
#   4290.15678319328,
#   'SE',
#   'Nossa Senhora do Socorro',
#   datetime.date(2023, 12, 16)),
#  (87,
#   41,
#   'André',
#   91,
#   'Caixa de Som',
#   96.82795406801182,
#   31699.717084921824,
#   'AP',
#   'Laranjal do Jari',
#   datetime.date(2021, 2, 19)),
#  (88,
#   74,
#   'Clara',
#   24,
#   'Caixa de Som',
#   11.38462932425168,
#   775.9155734538184,
#   'AM',
#   'Manaus',
#   datetime.date(2021, 7, 11)),
#  (89,
#   51,
#   'Arthur',
#   87,
#   'Smartwatch',
#   15.98104970070631,
#   9117.391307528727,
#   'MT',
#   'Rondonópolis',
#   datetime.date(2021, 3, 18)),
#  (90,
#   57,
#   'Davi',
#   43,
#   'Roteador',
#   42.16696225611538,
#   14126.45884690051,
#   'PI',
#   'Parnaíba',
#   datetime.date(2025, 1, 27)),
#  (91,
#   35,
#   'Nathan',
#   30,
#   'Monitor',
#   53.8913773372318,
#   9565.076513940438,
#   'PI',
#   'Parnaíba',
#   datetime.date(2025, 1, 29)),
#  (92,
#   14,
#   'Helena',
#   62,
#   'Monitor',
#   30.802843076794243,
#   4075.4573403149884,
#   'GO',
#   'Goiânia',
#   datetime.date(2022, 5, 25)),
#  (93,
#   70,
#   'Priscila',
#   24,
#   'Roteador',
#   2.308935913293054,
#   432.9033671405483,
#   'MT',
#   'Várzea Grande',
#   datetime.date(2024, 9, 27)),
#  (94,
#   76,
#   'Luísa',
#   51,
#   'Câmera',
#   15.194674440586716,
#   4257.8613386928855,
#   'MG',
#   'Contagem',
#   datetime.date(2021, 10, 30)),
#  (95,
#   22,
#   'Cecília',
#   46,
#   'Roteador',
#   66.7253665587617,
#   15062.822657115723,
#   'PI',
#   'Parnaíba',
#   datetime.date(2024, 6, 29)),
#  (96,
#   94,
#   'Júlia',
#   37,
#   'Impressora',
#   20.104983415394653,
#   5174.014885960045,
#   'PA',
#   'Santarém',
#   datetime.date(2024, 1, 6)),
#  (97,
#   42,
#   'Aline',
#   83,
#   'Smartphone',
#   47.52200239198552,
#   30912.05525747655,
#   'PE',
#   'Olinda',
#   datetime.date(2022, 7, 9)),
#  (98,
#   17,
#   'Laura',
#   75,
#   'Tablet',
#   66.38693684049645,
#   25795.704161499685,
#   'RJ',
#   'Duque de Caxias',
#   datetime.date(2020, 12, 23)),
#  (99,
#   21,
#   'Leonardo',
#   5,
#   'Roteador',
#   91.51433576914567,
#   1713.623127774425,
#   'MG',
#   'Uberlândia',
#   datetime.date(2020, 11, 14)),
#  (100,
#   80,
#   'Talita',
#   65,
#   'Caixa de Som',
#   62.991821272577376,
#   7983.519044637507,
#   'PR',
#   'Curitiba',
#   datetime.date(2022, 6, 20))]

# %%
spark = SparkSession.builder.appName(name="ecommerce").getOrCreate()
# Out:
# 25/02/23 14:25:16 WARN Utils: Your hostname, ademir resolves to a loopback address: 127.0.1.1; using 192.168.15.11 instead (on interface eno1)
# 25/02/23 14:25:16 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/02/23 14:25:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Definindo o schema

schema = StructType([
    StructField("nrPedido", IntegerType(), True),
    StructField("codCliente", IntegerType(), True),
    StructField("cliente", StringType(), True),
    StructField("qtd", IntegerType(), True),
    StructField("produto", StringType(), True),
    StructField("custo", FloatType(), True),
    StructField("valorVenda", FloatType(), True),
    StructField("uf", StringType(), True),
    StructField("cidade", StringType(), True),
    StructField("data", DateType(), True),
    
])

# %%
# Gerando dados fictícios de clientes para o DF
dados_vendas = gerardados(nome_cliente, estado_cidade, produtos)

# %%
# Atribuindo os dados ao df
df = spark.createDataFrame(dados_vendas, schema)

# %%
# Prévia dos dados.
df.limit(10).show(truncate = False)
# Out:
# 25/02/23 14:25:31 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+
# |nrPedido|codCliente|cliente |qtd|produto     |custo    |valorVenda|uf |cidade              |data      |
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+
# |1       |99        |Aline   |70 |Monitor     |29.054758|13038.509 |DF |Brasília            |2023-11-23|
# |2       |96        |Mariana |51 |Smartphone  |47.1931  |12252.802 |CE |Fortaleza           |2024-10-21|
# |3       |26        |Natália |38 |Monitor     |78.41565 |17539.277 |MT |Várzea Grande       |2021-08-11|
# |4       |63        |Cecília |33 |Monitor     |97.88951 |19262.916 |BA |Vitória da Conquista|2024-04-21|
# |5       |84        |Marina  |36 |Caixa de Som|24.012913|4575.9697 |BA |Vitória da Conquista|2023-06-24|
# |6       |76        |Carolina|93 |Monitor     |37.765675|19983.01  |AP |Santana             |2022-03-09|
# |7       |90        |Vitória |42 |Caixa de Som|47.58988 |14151.58  |BA |Salvador            |2023-08-06|
# |8       |83        |Samuel  |53 |Notebook    |14.648782|2440.4014 |MA |Timon               |2024-06-23|
# |9       |98        |Giovanna|9  |Câmera      |34.09242 |1001.70026|TO |Gurupi              |2023-02-21|
# |10      |99        |Gustavo |62 |Câmera      |34.02603 |9462.108  |RO |Porto Velho         |2020-08-04|
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+

# %%
# Identificando o schema
df.printSchema()
# Out:
# root
#  |-- nrPedido: integer (nullable = true)
#  |-- codCliente: integer (nullable = true)
#  |-- cliente: string (nullable = true)
#  |-- qtd: integer (nullable = true)
#  |-- produto: string (nullable = true)
#  |-- custo: float (nullable = true)
#  |-- valorVenda: float (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- cidade: string (nullable = true)
#  |-- data: date (nullable = true)

# %%
# Identificando o número total de linhas
df.count()
# Out:
# 100

# %%
# Estados que tiveram apenas uma venda, e qual produto foi vendido
df.filter(df.qtd == 1).select(df.uf, df.produto).show()
# Out:
# +---+-------+
# | uf|produto|
# +---+-------+
# | PB| Tablet|
# | AL|Monitor|
# +---+-------+

# %%
df.select(F.round(F.avg(F.col("valorVenda")), 2).alias("MediaVendas")).show()
# Out:
# +-----------+
# |MediaVendas|
# +-----------+
# |   10256.36|
# +-----------+

# %%
## Forma alternativa para obter a média (complexa)

# Média de vendas
df_media_vendas = df.agg({"valorVenda": "avg"})

# Imprimindo e renomeando a coluna com o cálculo médio para melhor compreensão.
df_media_vendas = df_media_vendas.withColumnRenamed("avg(valorVenda)", "MediaVendas")

df_media_vendas.select(F.round(df_media_vendas.MediaVendas,2).alias("MediaVendas")).show()
# Out:
# +-----------+
# |MediaVendas|
# +-----------+
# |   10256.36|
# +-----------+

# %%
# Produto mais vendido
#df.select(F.max("qtd")).show()
#df.orderBy(F.desc("qtd")).select("produto", "qtd").limit(1).show()
df_qtd_max = df.groupBy("produto").max("qtd").alias("total")
df_qtd_max.orderBy(F.desc("max(qtd)")).limit(3).show()
# Out:
# +----------+--------+
# |   produto|max(qtd)|
# +----------+--------+
# |  Roteador|     100|
# |Smartwatch|      95|
# |    Tablet|      95|
# +----------+--------+

# %%
df.groupBy("produto").sum("valorVenda").show()
# Out:
# +--------------+------------------+
# |       produto|   sum(valorVenda)|
# +--------------+------------------+
# |  Caixa de Som| 149799.5928955078|
# |    Smartwatch| 144988.2940826416|
# |      Roteador|103068.70123291016|
# |        Câmera|44454.198791503906|
# |      Notebook|  137872.904296875|
# |        Tablet| 57417.63146972656|
# |    Smartphone|116491.05737304688|
# |       Monitor| 88980.95609283447|
# |    Impressora|111504.70118713379|
# |Fone de Ouvido|  71057.5959777832|
# +--------------+------------------+

# %%
df2 = (
    df.groupBy("Produto")
    .sum("valorVenda")
    .show(n=10)     
)
# Out:
# +--------------+------------------+
# |       Produto|   sum(valorVenda)|
# +--------------+------------------+
# |  Caixa de Som| 149799.5928955078|
# |    Smartwatch| 144988.2940826416|
# |      Roteador|103068.70123291016|
# |        Câmera|44454.198791503906|
# |      Notebook|  137872.904296875|
# |        Tablet| 57417.63146972656|
# |    Smartphone|116491.05737304688|
# |       Monitor| 88980.95609283447|
# |    Impressora|111504.70118713379|
# |Fone de Ouvido|  71057.5959777832|
# +--------------+------------------+

# %%
dfduplicados = (
    df.groupBy(df.produto)
    .count()
    .filter(col("count") > 1)
    .sort("count", ascending=False)
    .limit(10)
    .show()
)
# Out:
# +--------------+-----+
# |       produto|count|
# +--------------+-----+
# |  Caixa de Som|   13|
# |        Tablet|   12|
# |    Smartwatch|   11|
# |      Notebook|   11|
# |    Impressora|   10|
# |Fone de Ouvido|   10|
# |        Câmera|    9|
# |    Smartphone|    9|
# |       Monitor|    8|
# |      Roteador|    7|
# +--------------+-----+

# %%
# Dropando dados duplicados
df.dropDuplicates().show(10)
# Out:
# +--------+----------+-------+---+------------+---------+----------+---+----------------+----------+
# |nrPedido|codCliente|cliente|qtd|     produto|    custo|valorVenda| uf|          cidade|      data|
# +--------+----------+-------+---+------------+---------+----------+---+----------------+----------+
# |      11|        41|    Ana| 35|    Roteador| 8.932827|  675.5731| AP|Laranjal do Jari|2022-08-19|
# |      21|        21|  Pedro| 85|  Smartwatch|32.624226| 10713.777| SE|         Lagarto|2021-01-21|
# |       2|        96|Mariana| 51|  Smartphone|  47.1931| 12252.802| CE|       Fortaleza|2024-10-21|
# |       7|        90|Vitória| 42|Caixa de Som| 47.58988|  14151.58| BA|        Salvador|2023-08-06|
# |       1|        99|  Aline| 70|     Monitor|29.054758| 13038.509| DF|        Brasília|2023-11-23|
# |       3|        26|Natália| 38|     Monitor| 78.41565| 17539.277| MT|   Várzea Grande|2021-08-11|
# |      18|        67|  Aline| 57|    Roteador| 89.70493|  39127.48| MA|           Timon|2023-03-25|
# |      15|        29|Cecília| 22|Caixa de Som|44.084236|  6663.271| ES|           Serra|2022-02-28|
# |      22|        47|  Elisa| 95|      Tablet| 78.45861| 11247.683| RN|           Natal|2021-03-02|
# |      10|        99|Gustavo| 62|      Câmera| 34.02603|  9462.108| RO|     Porto Velho|2020-08-04|
# +--------+----------+-------+---+------------+---------+----------+---+----------------+----------+
# only showing top 10 rows

# %%
# 5. *Custo Médio por Estado:  - Qual é o custo médio dos produtos vendidos em cada estado?
df.select(round(F.avg(col("custo")),2).alias("custoMedio")).show()
# Out:
# +----------+
# |custoMedio|
# +----------+
# |     51.66|
# +----------+

# %%
# 6. *Total de Vendas por Cliente: Qual é o total de vendas (valor de venda) por cliente?

df_total_por_clientes = (
    df
    .groupBy("cliente")
    .agg(F.round(F.sum("valorVenda"),2).alias("totalPorCliente"))
    .withColumnRenamed("sum(valorVenda)", "totalPorCliente")
    .show(10)
)
# Out:
# +--------+---------------+
# | cliente|totalPorCliente|
# +--------+---------------+
# |   Tomás|       74679.01|
# | Cecília|       33228.39|
# |Carolina|       19983.01|
# | Natália|       18349.95|
# |    Alex|       42891.82|
# |Giovanna|         1001.7|
# |   Pedro|       15581.03|
# | Beatriz|       26622.16|
# |     Ana|        5101.23|
# |  Felipe|       12298.44|
# +--------+---------------+
# only showing top 10 rows

# %%
# 7. Data Mais Recente e Mais Antiga: Qual é a data mais recente e a mais antiga registrada nos dados?
df_antigo_recente = (
    df
    .select(min(df.data)
    .alias("antigo"),
    max(df.data)
    .alias("recente"))
    .show()
)
# Out:
# +----------+----------+
# |    antigo|   recente|
# +----------+----------+
# |2020-02-28|2025-01-30|
# +----------+----------+

# %%
# 8. *Quantidade de Vendas por Dia: Quantas vendas ocorreram em cada dia?
df_total_diario = (
    df
    .groupBy(date_format("data", "dd/MM/yyyy").alias("data"))
    .agg(round(sum("valorVenda"),2)
    .alias("TotalVendaDiaria"))
    .limit(10)
    .show()
)
# Out:
# +----------+----------------+
# |      data|TotalVendaDiaria|
# +----------+----------------+
# |04/08/2020|         9462.11|
# |22/06/2021|         8567.58|
# |24/01/2022|         5619.94|
# |28/02/2022|         6663.27|
# |21/01/2021|        10713.78|
# |24/06/2023|         4575.97|
# |06/01/2021|        15834.59|
# |25/03/2023|        39127.48|
# |06/08/2023|        14151.58|
# |11/08/2021|        17539.28|
# +----------+----------------+

# %%
# 9. *Custo Médio e Valor de Venda Médio por Produto: Qual é o custo médio e o valor de venda médio para cada produto?
df_custoMedio_vendaMedia = (
    df.groupBy("produto")    
    .agg(round(avg("custo"),2)    
    .alias("custoMedio"),
    round(avg("valorVenda"))
    .alias("receitaMedia"))
    .limit(10)
    .show()
)
# Out:
# +--------------+----------+------------+
# |       produto|custoMedio|receitaMedia|
# +--------------+----------+------------+
# |  Caixa de Som|     49.76|     11523.0|
# |    Smartwatch|     61.47|     13181.0|
# |      Roteador|     43.89|     14724.0|
# |        Câmera|     46.32|      4939.0|
# |      Notebook|     45.18|     12534.0|
# |        Tablet|     50.11|      4785.0|
# |    Smartphone|     54.04|     12943.0|
# |       Monitor|     55.68|     11123.0|
# |    Impressora|     43.51|     11150.0|
# |Fone de Ouvido|     65.34|      7106.0|
# +--------------+----------+------------+

# %%
# 10. *Porcentagem de Lucro: Qual é a porcentagem média de lucro (baseado no custo e valor de venda) em todas as vendas?
custo_venda = df.withColumn("custoTotal", (df.qtd * df.custo))
custo_venda.show()
# Out:
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+----------+
# |nrPedido|codCliente| cliente|qtd|     produto|    custo|valorVenda| uf|              cidade|      data|custoTotal|
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+----------+
# |       1|        99|   Aline| 70|     Monitor|29.054758| 13038.509| DF|            Brasília|2023-11-23|  2033.833|
# |       2|        96| Mariana| 51|  Smartphone|  47.1931| 12252.802| CE|           Fortaleza|2024-10-21| 2406.8481|
# |       3|        26| Natália| 38|     Monitor| 78.41565| 17539.277| MT|       Várzea Grande|2021-08-11| 2979.7947|
# |       4|        63| Cecília| 33|     Monitor| 97.88951| 19262.916| BA|Vitória da Conquista|2024-04-21| 3230.3538|
# |       5|        84|  Marina| 36|Caixa de Som|24.012913| 4575.9697| BA|Vitória da Conquista|2023-06-24| 864.46484|
# |       6|        76|Carolina| 93|     Monitor|37.765675|  19983.01| AP|             Santana|2022-03-09| 3512.2078|
# |       7|        90| Vitória| 42|Caixa de Som| 47.58988|  14151.58| BA|            Salvador|2023-08-06|  1998.775|
# |       8|        83|  Samuel| 53|    Notebook|14.648782| 2440.4014| MA|               Timon|2024-06-23| 776.38544|
# |       9|        98|Giovanna|  9|      Câmera| 34.09242|1001.70026| TO|              Gurupi|2023-02-21| 306.83176|
# |      10|        99| Gustavo| 62|      Câmera| 34.02603|  9462.108| RO|         Porto Velho|2020-08-04|  2109.614|
# |      11|        41|     Ana| 35|    Roteador| 8.932827|  675.5731| AP|    Laranjal do Jari|2022-08-19| 312.64896|
# |      12|        88|    Alex| 18|Caixa de Som| 70.79604| 3876.0347| AM|           Parintins|2023-02-17| 1274.3287|
# |      13|        94|  Otávio|  1|      Tablet|77.815475|  279.2069| PB|         João Pessoa|2022-01-11| 77.815475|
# |      14|        75|  Felipe| 36|    Notebook|35.121952| 5619.9404| BA|            Salvador|2022-01-24| 1264.3903|
# |      15|        29| Cecília| 22|Caixa de Som|44.084236|  6663.271| ES|               Serra|2022-02-28|  969.8532|
# |      16|         3|   Maria| 59|  Impressora|97.156166| 43857.797| RR|           Boa Vista|2022-09-03|  5732.214|
# |      17|        95|  Bianca| 58|Caixa de Som| 35.47621| 15834.589| AM|              Manaus|2021-01-06| 2057.6204|
# |      18|        67|   Aline| 57|    Roteador| 89.70493|  39127.48| MA|               Timon|2023-03-25|  5113.181|
# |      19|        77| Beatriz| 66|      Tablet| 25.32271|  8567.583| PB|         João Pessoa|2021-06-22| 1671.2988|
# |      20|        34|   Tomás| 91|    Notebook| 16.80705| 10541.686| TO|              Gurupi|2022-04-21| 1529.4417|
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+----------+
# only showing top 20 rows

# %%
lucro_percentual = custo_venda.withColumn("lucroPercentual", round((custo_venda.custoTotal * custo_venda.valorVenda) / 100))
lucro_percentual.show()
# Out:
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+----------+---------------+
# |nrPedido|codCliente| cliente|qtd|     produto|    custo|valorVenda| uf|              cidade|      data|custoTotal|lucroPercentual|
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+----------+---------------+
# |       1|        99|   Aline| 70|     Monitor|29.054758| 13038.509| DF|            Brasília|2023-11-23|  2033.833|       265182.0|
# |       2|        96| Mariana| 51|  Smartphone|  47.1931| 12252.802| CE|           Fortaleza|2024-10-21| 2406.8481|       294906.0|
# |       3|        26| Natália| 38|     Monitor| 78.41565| 17539.277| MT|       Várzea Grande|2021-08-11| 2979.7947|       522634.0|
# |       4|        63| Cecília| 33|     Monitor| 97.88951| 19262.916| BA|Vitória da Conquista|2024-04-21| 3230.3538|       622260.0|
# |       5|        84|  Marina| 36|Caixa de Som|24.012913| 4575.9697| BA|Vitória da Conquista|2023-06-24| 864.46484|        39558.0|
# |       6|        76|Carolina| 93|     Monitor|37.765675|  19983.01| AP|             Santana|2022-03-09| 3512.2078|       701845.0|
# |       7|        90| Vitória| 42|Caixa de Som| 47.58988|  14151.58| BA|            Salvador|2023-08-06|  1998.775|       282858.0|
# |       8|        83|  Samuel| 53|    Notebook|14.648782| 2440.4014| MA|               Timon|2024-06-23| 776.38544|        18947.0|
# |       9|        98|Giovanna|  9|      Câmera| 34.09242|1001.70026| TO|              Gurupi|2023-02-21| 306.83176|         3074.0|
# |      10|        99| Gustavo| 62|      Câmera| 34.02603|  9462.108| RO|         Porto Velho|2020-08-04|  2109.614|       199614.0|
# |      11|        41|     Ana| 35|    Roteador| 8.932827|  675.5731| AP|    Laranjal do Jari|2022-08-19| 312.64896|         2112.0|
# |      12|        88|    Alex| 18|Caixa de Som| 70.79604| 3876.0347| AM|           Parintins|2023-02-17| 1274.3287|        49393.0|
# |      13|        94|  Otávio|  1|      Tablet|77.815475|  279.2069| PB|         João Pessoa|2022-01-11| 77.815475|          217.0|
# |      14|        75|  Felipe| 36|    Notebook|35.121952| 5619.9404| BA|            Salvador|2022-01-24| 1264.3903|        71058.0|
# |      15|        29| Cecília| 22|Caixa de Som|44.084236|  6663.271| ES|               Serra|2022-02-28|  969.8532|        64624.0|
# |      16|         3|   Maria| 59|  Impressora|97.156166| 43857.797| RR|           Boa Vista|2022-09-03|  5732.214|      2514023.0|
# |      17|        95|  Bianca| 58|Caixa de Som| 35.47621| 15834.589| AM|              Manaus|2021-01-06| 2057.6204|       325816.0|
# |      18|        67|   Aline| 57|    Roteador| 89.70493|  39127.48| MA|               Timon|2023-03-25|  5113.181|      2000659.0|
# |      19|        77| Beatriz| 66|      Tablet| 25.32271|  8567.583| PB|         João Pessoa|2021-06-22| 1671.2988|       143190.0|
# |      20|        34|   Tomás| 91|    Notebook| 16.80705| 10541.686| TO|              Gurupi|2022-04-21| 1529.4417|       161229.0|
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+----------+---------------+
# only showing top 20 rows

# %% [markdown]
# # Trabalhando com datas

# %%
#11) Data Mais Recente e Mais Antiga: Objetivo: Descobrir qual é a data mais recente e a mais antiga registrada nos dados.

data_recente_antiga = (
    df.select(
        F.max(date_format(df.data, "dd/MM/yyyy"))
        .alias("dataAntiga"), 
        F.min(date_format("data", "dd/MM/yyyy"))
        .alias("dataRecente"))
)

data_recente_antiga.show()
# Out:
# +----------+-----------+
# |dataAntiga|dataRecente|
# +----------+-----------+
# |31/08/2023| 01/03/2024|
# +----------+-----------+

# %%
df.select(F.min(df.data).alias("dataAntiga")).show()
# Out:
# +----------+
# |dataAntiga|
# +----------+
# |2020-02-28|
# +----------+

# %%
# 12) Quantidade de Vendas por Dia. Objetivo: Contar quantas vendas ocorreram em cada dia.
#df.groupBy("data").agg(sum("qtd").alias("qtdDia")).show()
df_qtdDia = (
    df.groupBy("data")
    .agg(sum("qtd").alias("qtdDia"))    
    .sort("data")
)

df_qtdDia.show()
# Out:
# +----------+------+
# |      data|qtdDia|
# +----------+------+
# |2020-02-28|    38|
# |2020-03-03|    59|
# |2020-03-06|    39|
# |2020-03-23|    86|
# |2020-04-13|    12|
# |2020-04-20|    30|
# |2020-04-29|    37|
# |2020-05-12|    56|
# |2020-05-27|     9|
# |2020-06-19|    19|
# |2020-08-04|    62|
# |2020-11-08|    91|
# |2020-12-24|    33|
# |2021-01-06|    58|
# |2021-01-18|    67|
# |2021-01-21|    85|
# |2021-02-06|    77|
# |2021-02-09|    73|
# |2021-02-12|     6|
# |2021-03-02|    95|
# +----------+------+
# only showing top 20 rows

# %% [markdown]
# ### Adicionar Coluna com Ano e Mês. Objetivo: Adicionar uma coluna que contenha apenas o ano e o mês da data da venda.

# %%
# 13) Adicionar Coluna com Ano e Mês Objetivo: Adicionar uma coluna que contenha apenas o ano e o mês da data da venda.
df_ano_mes = df.withColumn("ano_mes", date_format(df.data, "yyyy-MM"))
df_ano_mes.show()
# Out:
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+-------+
# |nrPedido|codCliente| cliente|qtd|     produto|    custo|valorVenda| uf|              cidade|      data|ano_mes|
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+-------+
# |       1|        99|   Aline| 70|     Monitor|29.054758| 13038.509| DF|            Brasília|2023-11-23|2023-11|
# |       2|        96| Mariana| 51|  Smartphone|  47.1931| 12252.802| CE|           Fortaleza|2024-10-21|2024-10|
# |       3|        26| Natália| 38|     Monitor| 78.41565| 17539.277| MT|       Várzea Grande|2021-08-11|2021-08|
# |       4|        63| Cecília| 33|     Monitor| 97.88951| 19262.916| BA|Vitória da Conquista|2024-04-21|2024-04|
# |       5|        84|  Marina| 36|Caixa de Som|24.012913| 4575.9697| BA|Vitória da Conquista|2023-06-24|2023-06|
# |       6|        76|Carolina| 93|     Monitor|37.765675|  19983.01| AP|             Santana|2022-03-09|2022-03|
# |       7|        90| Vitória| 42|Caixa de Som| 47.58988|  14151.58| BA|            Salvador|2023-08-06|2023-08|
# |       8|        83|  Samuel| 53|    Notebook|14.648782| 2440.4014| MA|               Timon|2024-06-23|2024-06|
# |       9|        98|Giovanna|  9|      Câmera| 34.09242|1001.70026| TO|              Gurupi|2023-02-21|2023-02|
# |      10|        99| Gustavo| 62|      Câmera| 34.02603|  9462.108| RO|         Porto Velho|2020-08-04|2020-08|
# |      11|        41|     Ana| 35|    Roteador| 8.932827|  675.5731| AP|    Laranjal do Jari|2022-08-19|2022-08|
# |      12|        88|    Alex| 18|Caixa de Som| 70.79604| 3876.0347| AM|           Parintins|2023-02-17|2023-02|
# |      13|        94|  Otávio|  1|      Tablet|77.815475|  279.2069| PB|         João Pessoa|2022-01-11|2022-01|
# |      14|        75|  Felipe| 36|    Notebook|35.121952| 5619.9404| BA|            Salvador|2022-01-24|2022-01|
# |      15|        29| Cecília| 22|Caixa de Som|44.084236|  6663.271| ES|               Serra|2022-02-28|2022-02|
# |      16|         3|   Maria| 59|  Impressora|97.156166| 43857.797| RR|           Boa Vista|2022-09-03|2022-09|
# |      17|        95|  Bianca| 58|Caixa de Som| 35.47621| 15834.589| AM|              Manaus|2021-01-06|2021-01|
# |      18|        67|   Aline| 57|    Roteador| 89.70493|  39127.48| MA|               Timon|2023-03-25|2023-03|
# |      19|        77| Beatriz| 66|      Tablet| 25.32271|  8567.583| PB|         João Pessoa|2021-06-22|2021-06|
# |      20|        34|   Tomás| 91|    Notebook| 16.80705| 10541.686| TO|              Gurupi|2022-04-21|2022-04|
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+-------+
# only showing top 20 rows

# %%
# 14) Filtrar Vendas de um Mês Específico. Objetivo: Filtrar todas as vendas que ocorreram no mês de julho de 2024.
df.filter((year(col("data")) == 2024) & (month(col("data")) == 6)).show(10)
# Out:
# +--------+----------+-------+---+--------+---------+----------+---+------+----------+
# |nrPedido|codCliente|cliente|qtd| produto|    custo|valorVenda| uf|cidade|      data|
# +--------+----------+-------+---+--------+---------+----------+---+------+----------+
# |       8|        83| Samuel| 53|Notebook|14.648782| 2440.4014| MA| Timon|2024-06-23|
# +--------+----------+-------+---+--------+---------+----------+---+------+----------+

# %% [markdown]
# #### Adicionar Coluna com Dia da Semana. Objetivo: Adicionar uma coluna que mostre o dia da semana para cada data de venda.

# %%
# 15) Adicionar Coluna com Dia da Semana. Objetivo: Adicionar uma coluna que mostre o dia da semana para cada data de venda.
df_dia_semana = df.withColumn("dia_semana", date_format(df.data, "EEEE"))
df_dia_semana.show()
# Out:
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+----------+
# |nrPedido|codCliente| cliente|qtd|     produto|    custo|valorVenda| uf|              cidade|      data|dia_semana|
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+----------+
# |       1|        99|   Aline| 70|     Monitor|29.054758| 13038.509| DF|            Brasília|2023-11-23|  Thursday|
# |       2|        96| Mariana| 51|  Smartphone|  47.1931| 12252.802| CE|           Fortaleza|2024-10-21|    Monday|
# |       3|        26| Natália| 38|     Monitor| 78.41565| 17539.277| MT|       Várzea Grande|2021-08-11| Wednesday|
# |       4|        63| Cecília| 33|     Monitor| 97.88951| 19262.916| BA|Vitória da Conquista|2024-04-21|    Sunday|
# |       5|        84|  Marina| 36|Caixa de Som|24.012913| 4575.9697| BA|Vitória da Conquista|2023-06-24|  Saturday|
# |       6|        76|Carolina| 93|     Monitor|37.765675|  19983.01| AP|             Santana|2022-03-09| Wednesday|
# |       7|        90| Vitória| 42|Caixa de Som| 47.58988|  14151.58| BA|            Salvador|2023-08-06|    Sunday|
# |       8|        83|  Samuel| 53|    Notebook|14.648782| 2440.4014| MA|               Timon|2024-06-23|    Sunday|
# |       9|        98|Giovanna|  9|      Câmera| 34.09242|1001.70026| TO|              Gurupi|2023-02-21|   Tuesday|
# |      10|        99| Gustavo| 62|      Câmera| 34.02603|  9462.108| RO|         Porto Velho|2020-08-04|   Tuesday|
# |      11|        41|     Ana| 35|    Roteador| 8.932827|  675.5731| AP|    Laranjal do Jari|2022-08-19|    Friday|
# |      12|        88|    Alex| 18|Caixa de Som| 70.79604| 3876.0347| AM|           Parintins|2023-02-17|    Friday|
# |      13|        94|  Otávio|  1|      Tablet|77.815475|  279.2069| PB|         João Pessoa|2022-01-11|   Tuesday|
# |      14|        75|  Felipe| 36|    Notebook|35.121952| 5619.9404| BA|            Salvador|2022-01-24|    Monday|
# |      15|        29| Cecília| 22|Caixa de Som|44.084236|  6663.271| ES|               Serra|2022-02-28|    Monday|
# |      16|         3|   Maria| 59|  Impressora|97.156166| 43857.797| RR|           Boa Vista|2022-09-03|  Saturday|
# |      17|        95|  Bianca| 58|Caixa de Som| 35.47621| 15834.589| AM|              Manaus|2021-01-06| Wednesday|
# |      18|        67|   Aline| 57|    Roteador| 89.70493|  39127.48| MA|               Timon|2023-03-25|  Saturday|
# |      19|        77| Beatriz| 66|      Tablet| 25.32271|  8567.583| PB|         João Pessoa|2021-06-22|   Tuesday|
# |      20|        34|   Tomás| 91|    Notebook| 16.80705| 10541.686| TO|              Gurupi|2022-04-21|  Thursday|
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+----------+
# only showing top 20 rows

# %%
# 16) Determinar o Dia da Semana com Mais Vendas
# Objetivo: Descobrir qual dia da semana teve o maior número de vendas totais (soma das quantidades vendidas).

df_dia_semana_total_qtd = (
    df_dia_semana
    .groupBy("dia_semana")
    .agg(sum("qtd").alias("qtd"))
    .sort("qtd", ascending=False)    
)
df_dia_semana_total_qtd.show()
# Out:
# +----------+----+
# |dia_semana| qtd|
# +----------+----+
# |    Monday|1051|
# |   Tuesday| 930|
# |    Sunday| 723|
# | Wednesday| 635|
# |    Friday| 577|
# |  Thursday| 365|
# |  Saturday| 287|
# +----------+----+

# %%
# 17) Calcular a Média de Vendas por Mês:
# Objetivo: Calcular a média da quantidade de vendas realizadas em cada mês.

df_media_vendas_mes = (
    df.groupBy(month("data")
               .alias("MesCorrespondente"))
    .agg(round(F.avg("valorVenda"),2)
         .alias("TotalPorMes"))
)
df_media_vendas_mes.show()
# Out:
# +-----------------+-----------+
# |MesCorrespondente|TotalPorMes|
# +-----------------+-----------+
# |                1|   11887.21|
# |                6|    9516.71|
# |                3|   12222.58|
# |                9|   13296.12|
# |                4|    8135.05|
# |                8|    8634.94|
# |                7|    6897.62|
# |               10|    8281.29|
# |               11|   16870.57|
# |                2|    6628.22|
# |                5|    7521.79|
# |               12|    3580.69|
# +-----------------+-----------+

# %%
#Exercício 20: Calcular a Média de Vendas por Produto em Cada Ano 
# Objetivo: Calcular a média de vendas realizadas para cada produto em cada ano. Utilize uma estrutura de repetição para iterar sobre os anos e calcular a média das vendas.

ano_venda = df.select(year(df.data).alias("ano")).distinct().sort("data").collect()

# %%
print(ano_venda)
# Out:
# [Row(ano=2020), Row(ano=2021), Row(ano=2022), Row(ano=2023), Row(ano=2024), Row(ano=2025)]

# %%
df_weekend = df.withColumn("dia_semana", date_format(df.data, "EEEE"))
df_weekend.filter((df_weekend.dia_semana ==  "Saturday") | (df_weekend.dia_semana == "Sunday")).show()
# Out:
# +--------+----------+--------+---+--------------+---------+----------+---+--------------------+----------+----------+
# |nrPedido|codCliente| cliente|qtd|       produto|    custo|valorVenda| uf|              cidade|      data|dia_semana|
# +--------+----------+--------+---+--------------+---------+----------+---+--------------------+----------+----------+
# |       4|        63| Cecília| 33|       Monitor| 97.88951| 19262.916| BA|Vitória da Conquista|2024-04-21|    Sunday|
# |       5|        84|  Marina| 36|  Caixa de Som|24.012913| 4575.9697| BA|Vitória da Conquista|2023-06-24|  Saturday|
# |       7|        90| Vitória| 42|  Caixa de Som| 47.58988|  14151.58| BA|            Salvador|2023-08-06|    Sunday|
# |       8|        83|  Samuel| 53|      Notebook|14.648782| 2440.4014| MA|               Timon|2024-06-23|    Sunday|
# |      16|         3|   Maria| 59|    Impressora|97.156166| 43857.797| RR|           Boa Vista|2022-09-03|  Saturday|
# |      18|        67|   Aline| 57|      Roteador| 89.70493|  39127.48| MA|               Timon|2023-03-25|  Saturday|
# |      23|        16|  Murilo| 84|      Roteador|41.510414| 10979.585| PB|         João Pessoa|2022-10-09|    Sunday|
# |      28|        84| Rafaela| 91|    Smartwatch| 89.53503|  29387.56| PE|              Olinda|2020-11-08|    Sunday|
# |      31|        56|  Felipe| 15|Fone de Ouvido| 82.87112|  6678.501| RR|        Rorainópolis|2022-09-17|  Saturday|
# |      35|        18|  Otávio|100|      Roteador| 74.10346| 13481.563| PE|Jaboatão dos Guar...|2022-01-02|    Sunday|
# |      40|         6| Cecília| 21|Fone de Ouvido| 79.80611|  7302.202| PR|            Londrina|2022-01-09|    Sunday|
# |      45|        58|  Nicole| 43|    Smartphone|24.225817| 3089.2058| MT|       Várzea Grande|2022-06-25|  Saturday|
# |      46|        36|Leonardo|  6|        Tablet|17.023829|  613.5382| RN|          Parnamirim|2024-01-14|    Sunday|
# |      47|        71|    Alex| 77|    Impressora|38.954727|   5802.26| GO|            Anápolis|2021-02-06|  Saturday|
# |      65|        57|  Yasmin| 27|Fone de Ouvido|2.5036678| 410.88858| AC|          Rio Branco|2024-03-31|    Sunday|
# |      73|        32|   Thaís| 30|      Notebook| 80.89635| 7566.2583| AC|          Rio Branco|2024-12-22|    Sunday|
# |      77|        96|   Laura| 95|    Smartwatch| 88.17927| 44226.145| TO|              Gurupi|2023-01-08|    Sunday|
# |      86|        78|  Renata| 12|        Tablet| 59.68932| 3992.1016| AM|         Itacoatiara|2023-02-26|    Sunday|
# |      89|        56|   Clara| 73|    Smartphone| 75.18959| 10133.526| RJ|             Niterói|2022-08-21|    Sunday|
# |      99|        50| Larissa| 56|      Roteador|83.401436|  36963.58| GO|            Anápolis|2024-01-28|    Sunday|
# +--------+----------+--------+---+--------------+---------+----------+---+--------------------+----------+----------+

# %%
df.filter(F.col("uf") == "SP").limit(3).show()
# Out:
# +--------+----------+-------+---+----------+---------+----------+---+---------+----------+
# |nrPedido|codCliente|cliente|qtd|   produto|    custo|valorVenda| uf|   cidade|      data|
# +--------+----------+-------+---+----------+---------+----------+---+---------+----------+
# |      93|        51|  Pedro| 29|Impressora| 42.44026| 4867.2534| SP|São Paulo|2023-06-26|
# |      95|        56|  Aline| 37|    Câmera|48.165436|  8294.692| SP|São Paulo|2020-04-29|
# +--------+----------+-------+---+----------+---------+----------+---+---------+----------+

# %% [markdown]
#
#
#
#
#
#
#
#
# 25. Comparação de Faturamento por Cidade
#    - Para cada estado, encontre a cidade com o maior faturamento total.
#
# 26. Identificar Vendas com Prejuízo
#    - Liste todas as vendas onde o custo (`custo * qtd`) foi maior que o valor de venda (`valorVenda * qtd`).
#
# 27. Clientes que Compraram Apenas Uma Vez
#    - Encontre os clientes que realizaram apenas um pedido no e-commerce.
#
# 28. Produto Mais Vendido em Cada Estado
#    - Descubra qual produto teve a maior quantidade vendida em cada estado (`uf`).
#
# 29. Crescimento Mensal do Faturamento
#    - Calcule o crescimento percentual do faturamento mês a mês.
#
# 30. Cliente com Maior Ticket Médio
#    - Encontre o cliente que possui o maior ticket médio, considerando apenas aqueles que realizaram pelo menos 5 compras.

# %%
#21. Clientes com Mais Compras  
#   Identifique os 5 clientes que mais realizaram compras, considerando a quantidade total de itens (`qtd`). 

df.orderBy(F.col("qtd").desc()).limit(5).show()
# Out:
# +--------+----------+--------+---+----------+---------+----------+---+--------------------+----------+
# |nrPedido|codCliente| cliente|qtd|   produto|    custo|valorVenda| uf|              cidade|      data|
# +--------+----------+--------+---+----------+---------+----------+---+--------------------+----------+
# |      35|        18|  Otávio|100|  Roteador| 74.10346| 13481.563| PE|Jaboatão dos Guar...|2022-01-02|
# |      77|        96|   Laura| 95|Smartwatch| 88.17927| 44226.145| TO|              Gurupi|2023-01-08|
# |      22|        47|   Elisa| 95|    Tablet| 78.45861| 11247.683| RN|               Natal|2021-03-02|
# |      30|         9| Rafaela| 94|    Câmera|20.562868|  6208.068| RO|           Ji-Paraná|2023-07-18|
# |       6|        76|Carolina| 93|   Monitor|37.765675|  19983.01| AP|             Santana|2022-03-09|
# +--------+----------+--------+---+----------+---------+----------+---+--------------------+----------+

# %%
#22. Estados com Maior Receita  
# Liste os estados (`uf`) ordenados pela maior receita total (`valorVenda`). 

df.orderBy(F.col("valorVenda").desc()).limit(10).show()
# Out:
# +--------+----------+-------+---+--------------+---------+----------+---+-----------+----------+
# |nrPedido|codCliente|cliente|qtd|       produto|    custo|valorVenda| uf|     cidade|      data|
# +--------+----------+-------+---+--------------+---------+----------+---+-----------+----------+
# |      71|        71|Emerson| 92|    Smartphone| 96.45083| 51860.176| GO|   Anápolis|2023-11-14|
# |      77|        96|  Laura| 95|    Smartwatch| 88.17927| 44226.145| TO|     Gurupi|2023-01-08|
# |      16|         3|  Maria| 59|    Impressora|97.156166| 43857.797| RR|  Boa Vista|2022-09-03|
# |      18|        67|  Aline| 57|      Roteador| 89.70493|  39127.48| MA|      Timon|2023-03-25|
# |      99|        50|Larissa| 56|      Roteador|83.401436|  36963.58| GO|   Anápolis|2024-01-28|
# |      70|        63|  Tomás| 76|      Notebook| 69.60904| 36880.152| GO|   Anápolis|2021-06-21|
# |      96|        14|   Raul| 89|  Caixa de Som| 54.16954| 31790.213| PE|     Olinda|2022-05-16|
# |      28|        84|Rafaela| 91|    Smartwatch| 89.53503|  29387.56| PE|     Olinda|2020-11-08|
# |      87|        57|   Alex| 87|      Notebook|81.095245| 23203.062| PE|     Recife|2023-01-18|
# |      49|        60| Evelyn| 39|Fone de Ouvido|  84.2756| 21093.256| RO|Porto Velho|2020-03-06|
# +--------+----------+-------+---+--------------+---------+----------+---+-----------+----------+

# %%
# 23. Produtos com Maior Faturamento  
#   - Quais são os 5 produtos que geraram o maior faturamento total (`valorVenda * qtd`)?  

df_faturamento = df.withColumn("total", df.valorVenda * df.qtd)
# Out:
# +--------+----------+-------+---+----------+---------+----------+---+-------------+----------+---------+
# |nrPedido|codCliente|cliente|qtd|   produto|    custo|valorVenda| uf|       cidade|      data|    total|
# +--------+----------+-------+---+----------+---------+----------+---+-------------+----------+---------+
# |       1|        99|  Aline| 70|   Monitor|29.054758| 13038.509| DF|     Brasília|2023-11-23| 912695.6|
# |       2|        96|Mariana| 51|Smartphone|  47.1931| 12252.802| CE|    Fortaleza|2024-10-21| 624892.9|
# |       3|        26|Natália| 38|   Monitor| 78.41565| 17539.277| MT|Várzea Grande|2021-08-11|666492.56|
# +--------+----------+-------+---+----------+---------+----------+---+-------------+----------+---------+

# %%
#df_faturamento.groupBy(df_faturamento.produto).agg(round(F.sum("total"),2).alias("total")).show()
df_faturamento.groupBy("produto") \
    .agg(F.round(F.sum("total"), 2).alias("total")) \
    .orderBy(F.desc("total")) \
    .show()
# Out:
# +--------------+-------------+
# |       produto|        total|
# +--------------+-------------+
# |    Smartwatch|1.159513512E7|
# |      Notebook|   9224774.17|
# |    Smartphone|   9131369.98|
# |  Caixa de Som|   8619675.82|
# |      Roteador|   6711068.63|
# |    Impressora|    6035281.6|
# |       Monitor|    4778100.0|
# |        Tablet|   2678313.99|
# |Fone de Ouvido|   2279039.28|
# |        Câmera|   2099139.35|
# +--------------+-------------+

# %%
#24. Ticket Médio por Cliente  
#   - Calcule o ticket médio por cliente, considerando a soma do `valorVenda` dividida pelo número de pedidos.  

df_ticket_medio = df.groupBy("codCliente").agg((F.sum("valorVenda") / F.sum("qtd")).alias("media"))
df_ticket_medio.show()
# Out:
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+
# |nrPedido|codCliente| cliente|qtd|     produto|    custo|valorVenda| uf|              cidade|      data|
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+
# |       1|        99|   Aline| 70|     Monitor|29.054758| 13038.509| DF|            Brasília|2023-11-23|
# |       2|        96| Mariana| 51|  Smartphone|  47.1931| 12252.802| CE|           Fortaleza|2024-10-21|
# |       3|        26| Natália| 38|     Monitor| 78.41565| 17539.277| MT|       Várzea Grande|2021-08-11|
# |       4|        63| Cecília| 33|     Monitor| 97.88951| 19262.916| BA|Vitória da Conquista|2024-04-21|
# |       5|        84|  Marina| 36|Caixa de Som|24.012913| 4575.9697| BA|Vitória da Conquista|2023-06-24|
# |       6|        76|Carolina| 93|     Monitor|37.765675|  19983.01| AP|             Santana|2022-03-09|
# |       7|        90| Vitória| 42|Caixa de Som| 47.58988|  14151.58| BA|            Salvador|2023-08-06|
# |       8|        83|  Samuel| 53|    Notebook|14.648782| 2440.4014| MA|               Timon|2024-06-23|
# |       9|        98|Giovanna|  9|      Câmera| 34.09242|1001.70026| TO|              Gurupi|2023-02-21|
# |      10|        99| Gustavo| 62|      Câmera| 34.02603|  9462.108| RO|         Porto Velho|2020-08-04|
# +--------+----------+--------+---+------------+---------+----------+---+--------------------+----------+
