# %%
# Importações básicas
import os
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql import DataFrame
from pyspark.sql import functions as F
from pyspark.sql.functions import *
from pyspark.sql.types import StructType,StructField, StringType, IntegerType, FloatType, DateType
from datetime import date, timedelta, datetime
import random
import calendar
from dateutil.relativedelta import relativedelta
import locale
import logging

# %%
logging.basicConfig(level=logging.INFO, filename="teste.log")

# %%
# Lista de clientes
nome_cliente = [
    "Ana", "João", "Maria", "Pedro", "Júlia", "Lucas", "Larissa", "Gabriel", "Beatriz", "Felipe", "Clara",
    "Daniel", "Laura", "Rafael", "Mariana", "Gustavo", "Luísa", "Henrique", "Sofia", "Matheus", "Isabella",
    "Bruno", "Alice", "Thiago", "Helena", "Rodrigo", "Giovanna", "Eduardo", "Rafaela", "Leonardo", "Nicole",
    "Caio", "Vitória", "André", "Fernanda", "Diego", "Yasmin", "Guilherme", "Letícia", "Vinícius", "Camila",
    "Igor", "Valentina", "Otávio", "Bianca", "Enzo", "Lorena", "Alex", "Elisa", "Murilo", "Vitória", "Samuel",
    "Gabriela", "Arthur", "Evelyn", "Miguel", "Marina", "Renan", "Tainá", "Jorge", "Juliana", "Samuel",
    "Melissa", "Raul", "Camila", "Levi", "Carolina", "Nathan", "Cecília", "Lucas", "Amanda", "Benjamin",
    "Lívia", "Heitor", "Bruna", "Davi", "Talita", "Theo", "Maíra", "Tomás", "Ana Clara", "Vicente", "Isadora",
    "Alexandre", "Sabrina", "Emerson", "Thaís", "Renata", "Otávio", "Priscila", "Eduardo", "Natália", "Jonas",
    "Aline", "Cristiano", "Patrícia", "Vicente", "Elisa"
]

# Lista de estados e cidades
estado_cidade = {
    "AC": ["Rio Branco", "Cruzeiro do Sul", "Sena Madureira"],
    "AL": ["Maceió", "Arapiraca", "Palmeira dos Índios"],
    "AP": ["Macapá", "Santana", "Laranjal do Jari"],
    "AM": ["Manaus", "Parintins", "Itacoatiara"],
    "BA": ["Salvador", "Feira de Santana", "Vitória da Conquista"],
    "CE": ["Fortaleza", "Caucaia", "Juazeiro do Norte"],
    "DF": ["Brasília"],
    "ES": ["Vitória", "Vila Velha", "Serra"],
    "GO": ["Goiânia", "Anápolis", "Aparecida de Goiânia"],
    "MA": ["São Luís", "Imperatriz", "Timon"],
    "MT": ["Cuiabá", "Várzea Grande", "Rondonópolis"],
    "MS": ["Campo Grande", "Dourados", "Três Lagoas"],
    "MG": ["Belo Horizonte", "Uberlândia", "Contagem"],
    "PA": ["Belém", "Ananindeua", "Santarém"],
    "PB": ["João Pessoa", "Campina Grande", "Santa Rita"],
    "PR": ["Curitiba", "Londrina", "Maringá"],
    "PE": ["Recife", "Jaboatão dos Guararapes", "Olinda"],
    "PI": ["Teresina", "Parnaíba", "Picos"],
    "RJ": ["Rio de Janeiro", "Niterói", "Duque de Caxias"],
    "RN": ["Natal", "Mossoró", "Parnamirim"],
    "RS": ["Porto Alegre", "Caxias do Sul", "Pelotas"],
    "RO": ["Porto Velho", "Ji-Paraná", "Ariquemes"],
    "RR": ["Boa Vista", "Rorainópolis", "Caracaraí"],
    "SC": ["Florianópolis", "Joinville", "Blumenau"],
    "SP": ["São Paulo", "Campinas", "São Bernardo do Campo"],
    "SE": ["Aracaju", "Nossa Senhora do Socorro", "Lagarto"],
    "TO": ["Palmas", "Araguaína", "Gurupi"]
}

# Lista de produtos eletrônicos
produtos = ["Smartphone", "Notebook", "Tablet", "Monitor", "Fone de Ouvido", "Smartwatch", "Câmera", "Impressora", "Caixa de Som", "Roteador"]

# %%
print(len(nome_cliente))
print(len(estado_cidade))
print(len(produtos))
# Out:
# 98
# 27
# 10

# %%
def gerardados(nome_cliente, estado_cidade, produtos):

    vendas = []
        
# Gera dados para número do pedido e código do cliente
    for dados in range(1,101):

        nrpedido = dados
        codcliente = random.randint(1, 100)  
        cliente = random.choice(nome_cliente)      
        qtd =  random.randint(1, 100)
        produto = random.choice(produtos)
        custo = float(random.uniform(1, 100))
        valor_venda = float(qtd * (custo * random.uniform(1.5, 8.0))) # Escolhe uma margem de lucro entre 1.5 e 8.0.
        data_inicial = date.today() - relativedelta(years=5)  # Captura a data atual e subtrai 5 anos.
        data_final = date.today()
        # Listando o período de data inicial e data final
        datas = [data_inicial + timedelta(days=i) for i in range((data_final - data_inicial).days + 1)]
        data = random.choice(datas)

        uf = random.choice(list(estado_cidade.keys()))
        cidade = random.choice(estado_cidade[uf])
        vendas.append((nrpedido, codcliente, cliente, qtd, produto, custo, valor_venda, uf, cidade, data))

    return vendas

# %%
gerardados(nome_cliente, estado_cidade, produtos)
# Out:
# [(1,
#   72,
#   'Nicole',
#   69,
#   'Monitor',
#   15.062154400094903,
#   4661.2028508944995,
#   'RR',
#   'Boa Vista',
#   datetime.date(2021, 6, 18)),
#  (2,
#   31,
#   'Elisa',
#   59,
#   'Smartphone',
#   88.86842808867858,
#   41505.5566989174,
#   'DF',
#   'Brasília',
#   datetime.date(2021, 4, 16)),
#  (3,
#   20,
#   'João',
#   52,
#   'Caixa de Som',
#   57.52226495917507,
#   10033.366026275402,
#   'MT',
#   'Rondonópolis',
#   datetime.date(2024, 7, 22)),
#  (4,
#   55,
#   'Elisa',
#   94,
#   'Tablet',
#   2.239934412569552,
#   1495.1789418203084,
#   'RR',
#   'Boa Vista',
#   datetime.date(2021, 8, 2)),
#  (5,
#   71,
#   'Melissa',
#   85,
#   'Smartphone',
#   2.0562203961526078,
#   375.82229283581796,
#   'AP',
#   'Laranjal do Jari',
#   datetime.date(2021, 4, 30)),
#  (6,
#   70,
#   'Eduardo',
#   100,
#   'Roteador',
#   4.091326316268823,
#   2714.2044063225667,
#   'RO',
#   'Ji-Paraná',
#   datetime.date(2022, 1, 12)),
#  (7,
#   2,
#   'Rodrigo',
#   25,
#   'Roteador',
#   28.58613339581907,
#   1731.999319887431,
#   'SE',
#   'Aracaju',
#   datetime.date(2024, 4, 16)),
#  (8,
#   67,
#   'Alexandre',
#   62,
#   'Smartwatch',
#   79.41881825241491,
#   22332.652734727846,
#   'PA',
#   'Belém',
#   datetime.date(2020, 6, 3)),
#  (9,
#   7,
#   'Thaís',
#   43,
#   'Fone de Ouvido',
#   72.5786510227736,
#   23129.01983948085,
#   'ES',
#   'Vila Velha',
#   datetime.date(2023, 4, 8)),
#  (10,
#   12,
#   'Jonas',
#   74,
#   'Tablet',
#   70.03538446848523,
#   16903.113855123145,
#   'RN',
#   'Mossoró',
#   datetime.date(2022, 8, 4)),
#  (11,
#   14,
#   'Otávio',
#   21,
#   'Impressora',
#   95.26495851819179,
#   5224.74952304597,
#   'GO',
#   'Anápolis',
#   datetime.date(2020, 6, 5)),
#  (12,
#   71,
#   'Elisa',
#   47,
#   'Caixa de Som',
#   63.46110971439437,
#   6580.652917180337,
#   'PB',
#   'João Pessoa',
#   datetime.date(2021, 6, 27)),
#  (13,
#   84,
#   'Aline',
#   5,
#   'Monitor',
#   82.20282446702477,
#   2847.1529686803956,
#   'RJ',
#   'Rio de Janeiro',
#   datetime.date(2022, 9, 23)),
#  (14,
#   1,
#   'Jonas',
#   76,
#   'Monitor',
#   73.9516262680787,
#   33160.72785210714,
#   'SE',
#   'Nossa Senhora do Socorro',
#   datetime.date(2023, 7, 28)),
#  (15,
#   38,
#   'Isadora',
#   20,
#   'Roteador',
#   76.46948117595994,
#   9669.56561776886,
#   'PE',
#   'Jaboatão dos Guararapes',
#   datetime.date(2022, 6, 30)),
#  (16,
#   35,
#   'Guilherme',
#   72,
#   'Smartphone',
#   53.59594566566113,
#   30085.56622192702,
#   'TO',
#   'Araguaína',
#   datetime.date(2024, 12, 6)),
#  (17,
#   76,
#   'Diego',
#   70,
#   'Fone de Ouvido',
#   45.22242629042037,
#   20871.85367172759,
#   'MT',
#   'Cuiabá',
#   datetime.date(2021, 7, 11)),
#  (18,
#   79,
#   'Larissa',
#   57,
#   'Monitor',
#   33.20130387761432,
#   8793.206253081387,
#   'TO',
#   'Palmas',
#   datetime.date(2022, 12, 24)),
#  (19,
#   28,
#   'Pedro',
#   44,
#   'Notebook',
#   6.6949108587728405,
#   1111.8487471897636,
#   'PA',
#   'Santarém',
#   datetime.date(2021, 7, 18)),
#  (20,
#   12,
#   'Renan',
#   48,
#   'Monitor',
#   59.00301531417691,
#   17346.06624555185,
#   'MG',
#   'Contagem',
#   datetime.date(2022, 6, 6)),
#  (21,
#   77,
#   'Aline',
#   4,
#   'Smartphone',
#   42.71808500412929,
#   1052.0376151237147,
#   'RR',
#   'Rorainópolis',
#   datetime.date(2021, 3, 15)),
#  (22,
#   21,
#   'Eduardo',
#   35,
#   'Smartphone',
#   30.07684729305861,
#   2577.7869355777743,
#   'RR',
#   'Rorainópolis',
#   datetime.date(2020, 10, 13)),
#  (23,
#   11,
#   'Lívia',
#   44,
#   'Tablet',
#   64.84494093514434,
#   21576.651972857395,
#   'RO',
#   'Porto Velho',
#   datetime.date(2021, 11, 10)),
#  (24,
#   66,
#   'Nicole',
#   95,
#   'Monitor',
#   15.150014146971154,
#   10424.757523496713,
#   'PE',
#   'Recife',
#   datetime.date(2020, 12, 7)),
#  (25,
#   17,
#   'Renan',
#   22,
#   'Câmera',
#   36.359456374160224,
#   2922.4327874826276,
#   'ES',
#   'Vitória',
#   datetime.date(2023, 11, 23)),
#  (26,
#   17,
#   'Beatriz',
#   76,
#   'Fone de Ouvido',
#   80.16151511358237,
#   18993.262702758864,
#   'SE',
#   'Nossa Senhora do Socorro',
#   datetime.date(2023, 3, 14)),
#  (27,
#   66,
#   'Ana Clara',
#   74,
#   'Impressora',
#   50.33095540221346,
#   8963.33217108184,
#   'PR',
#   'Curitiba',
#   datetime.date(2025, 1, 1)),
#  (28,
#   51,
#   'Vinícius',
#   62,
#   'Tablet',
#   20.82385489714481,
#   7745.84809561263,
#   'SE',
#   'Aracaju',
#   datetime.date(2021, 12, 17)),
#  (29,
#   13,
#   'Miguel',
#   25,
#   'Monitor',
#   69.90858967916878,
#   12440.833722563779,
#   'PA',
#   'Belém',
#   datetime.date(2022, 11, 25)),
#  (30,
#   4,
#   'Bruno',
#   30,
#   'Câmera',
#   30.516604970742122,
#   6518.9926453708595,
#   'GO',
#   'Goiânia',
#   datetime.date(2022, 2, 10)),
#  (31,
#   21,
#   'Júlia',
#   94,
#   'Monitor',
#   94.81419530250986,
#   30209.597623104844,
#   'RR',
#   'Boa Vista',
#   datetime.date(2024, 1, 16)),
#  (32,
#   5,
#   'Juliana',
#   80,
#   'Monitor',
#   90.68654726116615,
#   31107.764663630187,
#   'MA',
#   'São Luís',
#   datetime.date(2025, 1, 5)),
#  (33,
#   48,
#   'Vicente',
#   1,
#   'Roteador',
#   86.03754343613691,
#   560.8300240658555,
#   'PI',
#   'Parnaíba',
#   datetime.date(2021, 2, 23)),
#  (34,
#   3,
#   'Vinícius',
#   74,
#   'Impressora',
#   22.14584697356092,
#   2530.135121538363,
#   'RN',
#   'Natal',
#   datetime.date(2023, 2, 6)),
#  (35,
#   50,
#   'Elisa',
#   43,
#   'Smartwatch',
#   71.54298605602307,
#   5760.243490602138,
#   'MG',
#   'Belo Horizonte',
#   datetime.date(2023, 9, 9)),
#  (36,
#   72,
#   'Natália',
#   8,
#   'Câmera',
#   75.9832258930809,
#   3969.171067737777,
#   'PB',
#   'Santa Rita',
#   datetime.date(2020, 7, 1)),
#  (37,
#   79,
#   'Lívia',
#   39,
#   'Tablet',
#   84.5090443115235,
#   23174.599736680422,
#   'MG',
#   'Belo Horizonte',
#   datetime.date(2021, 12, 19)),
#  (38,
#   74,
#   'Bianca',
#   34,
#   'Monitor',
#   41.28831754593205,
#   3167.556674826388,
#   'RN',
#   'Mossoró',
#   datetime.date(2020, 4, 21)),
#  (39,
#   24,
#   'Isadora',
#   68,
#   'Monitor',
#   6.297767020419899,
#   2419.383102622786,
#   'AL',
#   'Maceió',
#   datetime.date(2023, 9, 28)),
#  (40,
#   30,
#   'Elisa',
#   72,
#   'Câmera',
#   70.46482315541503,
#   25917.395118677116,
#   'DF',
#   'Brasília',
#   datetime.date(2021, 3, 8)),
#  (41,
#   4,
#   'Davi',
#   82,
#   'Câmera',
#   92.43553436977813,
#   28327.599255900088,
#   'AL',
#   'Arapiraca',
#   datetime.date(2020, 6, 15)),
#  (42,
#   96,
#   'Luísa',
#   68,
#   'Fone de Ouvido',
#   91.93922887890086,
#   41228.711241384495,
#   'PI',
#   'Parnaíba',
#   datetime.date(2021, 6, 19)),
#  (43,
#   52,
#   'Carolina',
#   13,
#   'Notebook',
#   85.73406898133906,
#   1770.5348609026873,
#   'RS',
#   'Caxias do Sul',
#   datetime.date(2020, 3, 17)),
#  (44,
#   90,
#   'Clara',
#   5,
#   'Tablet',
#   52.54148334397931,
#   1573.2646118048863,
#   'SP',
#   'Campinas',
#   datetime.date(2021, 8, 25)),
#  (45,
#   78,
#   'Leonardo',
#   36,
#   'Monitor',
#   25.544900903401782,
#   4329.942571799293,
#   'SC',
#   'Florianópolis',
#   datetime.date(2025, 1, 14)),
#  (46,
#   48,
#   'Vitória',
#   38,
#   'Smartphone',
#   26.86280671487506,
#   5957.5318496962955,
#   'RJ',
#   'Niterói',
#   datetime.date(2021, 8, 18)),
#  (47,
#   72,
#   'Enzo',
#   38,
#   'Fone de Ouvido',
#   86.16826077679114,
#   15470.475507983227,
#   'BA',
#   'Vitória da Conquista',
#   datetime.date(2024, 3, 24)),
#  (48,
#   96,
#   'Thiago',
#   71,
#   'Fone de Ouvido',
#   77.18675251206744,
#   28338.096346241706,
#   'MT',
#   'Rondonópolis',
#   datetime.date(2023, 3, 11)),
#  (49,
#   87,
#   'Bianca',
#   40,
#   'Fone de Ouvido',
#   43.03956952977901,
#   11394.02701604173,
#   'MT',
#   'Rondonópolis',
#   datetime.date(2020, 5, 27)),
#  (50,
#   91,
#   'Samuel',
#   69,
#   'Fone de Ouvido',
#   94.13806211631223,
#   37514.063294693406,
#   'BA',
#   'Feira de Santana',
#   datetime.date(2023, 4, 10)),
#  (51,
#   62,
#   'Vitória',
#   6,
#   'Tablet',
#   32.505183613635566,
#   665.3520644107556,
#   'MA',
#   'Imperatriz',
#   datetime.date(2023, 8, 23)),
#  (52,
#   99,
#   'Vitória',
#   64,
#   'Smartphone',
#   32.93771546995484,
#   15231.806804094196,
#   'GO',
#   'Goiânia',
#   datetime.date(2020, 6, 18)),
#  (53,
#   22,
#   'Mariana',
#   57,
#   'Notebook',
#   77.98639530260554,
#   27256.26429214308,
#   'RO',
#   'Porto Velho',
#   datetime.date(2024, 11, 12)),
#  (54,
#   82,
#   'Renata',
#   96,
#   'Impressora',
#   15.393713699265506,
#   7707.303065570504,
#   'AM',
#   'Parintins',
#   datetime.date(2023, 5, 2)),
#  (55,
#   11,
#   'Theo',
#   23,
#   'Monitor',
#   67.87799847560723,
#   5431.978055783431,
#   'PI',
#   'Parnaíba',
#   datetime.date(2024, 5, 7)),
#  (56,
#   16,
#   'Priscila',
#   39,
#   'Notebook',
#   16.248390831700434,
#   1030.084194393791,
#   'PE',
#   'Recife',
#   datetime.date(2021, 10, 1)),
#  (57,
#   80,
#   'Helena',
#   67,
#   'Caixa de Som',
#   74.83250067134423,
#   20904.651094186676,
#   'PE',
#   'Jaboatão dos Guararapes',
#   datetime.date(2022, 6, 28)),
#  (58,
#   80,
#   'Murilo',
#   73,
#   'Fone de Ouvido',
#   41.780613083362994,
#   6529.358353798294,
#   'AL',
#   'Arapiraca',
#   datetime.date(2023, 3, 4)),
#  (59,
#   79,
#   'Leonardo',
#   22,
#   'Monitor',
#   32.822746524477395,
#   3402.1503503584554,
#   'SE',
#   'Aracaju',
#   datetime.date(2022, 2, 26)),
#  (60,
#   88,
#   'Rodrigo',
#   99,
#   'Monitor',
#   37.83489619787539,
#   18393.70469275364,
#   'AC',
#   'Cruzeiro do Sul',
#   datetime.date(2020, 6, 17)),
#  (61,
#   92,
#   'Bruna',
#   63,
#   'Câmera',
#   40.89699390770529,
#   9945.97178227785,
#   'SC',
#   'Florianópolis',
#   datetime.date(2023, 4, 7)),
#  (62,
#   33,
#   'Samuel',
#   22,
#   'Fone de Ouvido',
#   48.54750767694159,
#   6650.798573048324,
#   'MT',
#   'Várzea Grande',
#   datetime.date(2021, 2, 22)),
#  (63,
#   34,
#   'Gabriela',
#   57,
#   'Smartphone',
#   54.3044651744126,
#   11512.331089044801,
#   'DF',
#   'Brasília',
#   datetime.date(2022, 8, 20)),
#  (64,
#   57,
#   'Natália',
#   18,
#   'Smartphone',
#   58.244226358691556,
#   6441.463005420056,
#   'RJ',
#   'Duque de Caxias',
#   datetime.date(2022, 2, 2)),
#  (65,
#   92,
#   'Gabriel',
#   22,
#   'Câmera',
#   37.21904266704357,
#   1612.032612996688,
#   'RR',
#   'Caracaraí',
#   datetime.date(2023, 9, 13)),
#  (66,
#   3,
#   'Samuel',
#   74,
#   'Fone de Ouvido',
#   40.52450893211717,
#   8654.945584252124,
#   'PI',
#   'Parnaíba',
#   datetime.date(2020, 9, 23)),
#  (67,
#   4,
#   'Valentina',
#   85,
#   'Tablet',
#   12.17191527833173,
#   1927.6192682436285,
#   'MA',
#   'São Luís',
#   datetime.date(2025, 2, 14)),
#  (68,
#   77,
#   'Isadora',
#   50,
#   'Smartphone',
#   19.926525579555634,
#   2681.274858802703,
#   'PR',
#   'Maringá',
#   datetime.date(2022, 4, 16)),
#  (69,
#   1,
#   'Lorena',
#   32,
#   'Caixa de Som',
#   39.705798555846634,
#   6827.026221563656,
#   'RO',
#   'Ji-Paraná',
#   datetime.date(2022, 12, 11)),
#  (70,
#   73,
#   'Lucas',
#   91,
#   'Smartphone',
#   9.584403570046554,
#   3414.5881827963944,
#   'MA',
#   'Imperatriz',
#   datetime.date(2024, 4, 15)),
#  (71,
#   48,
#   'Elisa',
#   94,
#   'Monitor',
#   9.410001036788614,
#   5563.1936385376675,
#   'MA',
#   'Timon',
#   datetime.date(2023, 12, 3)),
#  (72,
#   14,
#   'Patrícia',
#   12,
#   'Smartphone',
#   64.35861570095622,
#   3391.301415013895,
#   'MA',
#   'São Luís',
#   datetime.date(2025, 1, 29)),
#  (73,
#   39,
#   'Maria',
#   78,
#   'Tablet',
#   66.18901814167829,
#   21352.40444481986,
#   'SP',
#   'Campinas',
#   datetime.date(2021, 5, 16)),
#  (74,
#   18,
#   'Thaís',
#   90,
#   'Roteador',
#   52.35066499017893,
#   31642.478564148867,
#   'MA',
#   'São Luís',
#   datetime.date(2021, 2, 24)),
#  (75,
#   32,
#   'Jorge',
#   85,
#   'Roteador',
#   89.72319818597026,
#   19139.282324749955,
#   'SP',
#   'São Bernardo do Campo',
#   datetime.date(2020, 11, 20)),
#  (76,
#   4,
#   'Diego',
#   34,
#   'Fone de Ouvido',
#   23.111104886640977,
#   1674.0935799958029,
#   'TO',
#   'Gurupi',
#   datetime.date(2021, 7, 8)),
#  (77,
#   4,
#   'Fernanda',
#   17,
#   'Impressora',
#   62.43042961043035,
#   6760.731164334128,
#   'CE',
#   'Fortaleza',
#   datetime.date(2022, 10, 27)),
#  (78,
#   9,
#   'Carolina',
#   26,
#   'Tablet',
#   26.330800383931447,
#   1492.3210385993102,
#   'BA',
#   'Vitória da Conquista',
#   datetime.date(2021, 6, 30)),
#  (79,
#   17,
#   'Heitor',
#   16,
#   'Impressora',
#   29.057265841738182,
#   2898.258427560598,
#   'RJ',
#   'Rio de Janeiro',
#   datetime.date(2021, 10, 17)),
#  (80,
#   39,
#   'Nathan',
#   78,
#   'Caixa de Som',
#   26.351052686540893,
#   9279.593462358745,
#   'SE',
#   'Lagarto',
#   datetime.date(2021, 9, 13)),
#  (81,
#   45,
#   'Talita',
#   78,
#   'Caixa de Som',
#   70.89761484233838,
#   25685.756371663447,
#   'RR',
#   'Caracaraí',
#   datetime.date(2024, 4, 25)),
#  (82,
#   72,
#   'Lorena',
#   10,
#   'Caixa de Som',
#   44.615497175672886,
#   1687.7841159994568,
#   'PE',
#   'Recife',
#   datetime.date(2021, 6, 18)),
#  (83,
#   93,
#   'Renata',
#   53,
#   'Fone de Ouvido',
#   25.09304591750887,
#   5149.696421515633,
#   'RS',
#   'Caxias do Sul',
#   datetime.date(2024, 9, 8)),
#  (84,
#   98,
#   'Helena',
#   8,
#   'Câmera',
#   67.63324578595855,
#   3280.282950232132,
#   'PR',
#   'Curitiba',
#   datetime.date(2023, 11, 18)),
#  (85,
#   12,
#   'Amanda',
#   55,
#   'Câmera',
#   75.36978137040042,
#   31320.956657352202,
#   'TO',
#   'Palmas',
#   datetime.date(2022, 1, 13)),
#  (86,
#   55,
#   'Amanda',
#   35,
#   'Caixa de Som',
#   49.566198604630834,
#   11682.75329645742,
#   'SP',
#   'São Paulo',
#   datetime.date(2023, 4, 9)),
#  (87,
#   83,
#   'Eduardo',
#   28,
#   'Notebook',
#   47.89113319130774,
#   4743.663827584984,
#   'MT',
#   'Várzea Grande',
#   datetime.date(2023, 5, 12)),
#  (88,
#   72,
#   'Fernanda',
#   38,
#   'Roteador',
#   88.78810500368935,
#   19162.025913269124,
#   'RS',
#   'Porto Alegre',
#   datetime.date(2020, 10, 27)),
#  (89,
#   47,
#   'Vitória',
#   70,
#   'Smartphone',
#   59.449718023622275,
#   11469.335237290794,
#   'PI',
#   'Parnaíba',
#   datetime.date(2020, 3, 31)),
#  (90,
#   57,
#   'Alexandre',
#   46,
#   'Smartphone',
#   83.97579933973302,
#   16372.429432943934,
#   'GO',
#   'Anápolis',
#   datetime.date(2022, 2, 10)),
#  (91,
#   84,
#   'Vinícius',
#   45,
#   'Tablet',
#   13.67503798432542,
#   4554.333172351231,
#   'PB',
#   'João Pessoa',
#   datetime.date(2023, 10, 3)),
#  (92,
#   95,
#   'Benjamin',
#   67,
#   'Smartphone',
#   18.544421524574,
#   4224.821943304294,
#   'GO',
#   'Anápolis',
#   datetime.date(2022, 11, 18)),
#  (93,
#   44,
#   'Pedro',
#   13,
#   'Smartwatch',
#   5.982446616989396,
#   255.83624927029314,
#   'SP',
#   'São Paulo',
#   datetime.date(2023, 12, 4)),
#  (94,
#   11,
#   'Rafaela',
#   83,
#   'Impressora',
#   76.55381071546422,
#   10947.428355543308,
#   'AM',
#   'Manaus',
#   datetime.date(2020, 3, 16)),
#  (95,
#   15,
#   'Luísa',
#   29,
#   'Monitor',
#   95.55938313371249,
#   21333.41546449497,
#   'DF',
#   'Brasília',
#   datetime.date(2020, 3, 11)),
#  (96,
#   64,
#   'Levi',
#   52,
#   'Caixa de Som',
#   13.589257330943719,
#   2151.806646715566,
#   'TO',
#   'Araguaína',
#   datetime.date(2025, 2, 18)),
#  (97,
#   60,
#   'Renan',
#   14,
#   'Smartwatch',
#   49.680749680782206,
#   1361.848610250285,
#   'MS',
#   'Três Lagoas',
#   datetime.date(2022, 12, 7)),
#  (98,
#   28,
#   'Miguel',
#   97,
#   'Smartphone',
#   63.89048359158487,
#   10461.372479234436,
#   'BA',
#   'Feira de Santana',
#   datetime.date(2020, 10, 28)),
#  (99,
#   98,
#   'Jonas',
#   14,
#   'Impressora',
#   55.55982322099702,
#   4965.222511451902,
#   'TO',
#   'Gurupi',
#   datetime.date(2024, 10, 18)),
#  (100,
#   3,
#   'Cecília',
#   36,
#   'Smartphone',
#   5.251035491702163,
#   492.03786553737734,
#   'MS',
#   'Três Lagoas',
#   datetime.date(2022, 12, 28))]

# %%
spark = SparkSession.builder.appName(name="ecommerce").getOrCreate()
# Out:
# 25/02/19 22:31:55 WARN Utils: Your hostname, ademir resolves to a loopback address: 127.0.1.1; using 192.168.15.11 instead (on interface eno1)
# 25/02/19 22:31:55 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/02/19 22:31:57 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Definindo o schema

schema = StructType([
    StructField("nrPedido", IntegerType(), True),
    StructField("codCliente", IntegerType(), True),
    StructField("cliente", StringType(), True),
    StructField("qtd", IntegerType(), True),
    StructField("produto", StringType(), True),
    StructField("custo", FloatType(), True),
    StructField("valorVenda", FloatType(), True),
    StructField("uf", StringType(), True),
    StructField("cidade", StringType(), True),
    StructField("data", DateType(), True),
    
])

# %%
# Gerando dados fictícios de clientes para o DF
dados_vendas = gerardados(nome_cliente, estado_cidade, produtos)

# %%
# Atribuindo os dados ao df
df = spark.createDataFrame(dados_vendas, schema)

# %%
# Prévia dos dados.
df.limit(10).show(truncate = False)
# Out:
# 25/02/19 22:32:12 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# +--------+----------+-------+---+----------+---------+----------+---+----------------+----------+
# |nrPedido|codCliente|cliente|qtd|produto   |custo    |valorVenda|uf |cidade          |data      |
# +--------+----------+-------+---+----------+---------+----------+---+----------------+----------+
# |1       |87        |Cecília|4  |Smartphone|63.57274 |533.02356 |DF |Brasília        |2021-10-30|
# |2       |93        |Arthur |85 |Câmera    |26.437727|17726.205 |MA |São Luís        |2023-09-15|
# |3       |39        |Maria  |89 |Impressora|59.264214|35238.35  |RS |Pelotas         |2023-09-04|
# |4       |53        |Sofia  |36 |Impressora|86.94093 |19559.494 |RJ |Niterói         |2022-12-25|
# |5       |33        |Bruna  |21 |Smartphone|88.32472 |6005.1646 |DF |Brasília        |2022-06-08|
# |6       |9         |Igor   |21 |Notebook  |65.64703 |5368.747  |MG |Belo Horizonte  |2025-01-08|
# |7       |83        |Camila |75 |Notebook  |54.604053|25832.822 |MS |Três Lagoas     |2020-02-26|
# |8       |66        |Davi   |60 |Impressora|29.419613|9790.599  |RR |Rorainópolis    |2022-07-09|
# |9       |93        |Thiago |100|Monitor   |76.63529 |54795.69  |AL |Maceió          |2022-12-12|
# |10      |87        |Vitória|61 |Roteador  |9.217255 |3558.069  |AP |Laranjal do Jari|2021-05-13|
# +--------+----------+-------+---+----------+---------+----------+---+----------------+----------+

# %%
# Identificando o schema
df.printSchema()
# Out:
# root
#  |-- nrPedido: integer (nullable = true)
#  |-- codCliente: integer (nullable = true)
#  |-- cliente: string (nullable = true)
#  |-- qtd: integer (nullable = true)
#  |-- produto: string (nullable = true)
#  |-- custo: float (nullable = true)
#  |-- valorVenda: float (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- cidade: string (nullable = true)
#  |-- data: date (nullable = true)

# %%
# Identificando o número total de linhas
df.count()
# Out:
# 100

# %%
# Estados que tiveram apenas uma venda, e qual produto foi vendido
df.filter(df.qtd == 1).select(df.uf, df.produto).show()
# Out:
# +---+----------+
# | uf|   produto|
# +---+----------+
# | AM|Smartphone|
# +---+----------+

# %%
df.select(F.round(F.avg(F.col("valorVenda")), 2).alias("MediaVendas")).show()
# Out:
# +-----------+
# |MediaVendas|
# +-----------+
# |   14384.61|
# +-----------+

# %%
## Forma alternativa para obter a média (complexa)

# Média de vendas
df_media_vendas = df.agg({"valorVenda": "avg"})

# Imprimindo e renomeando a coluna com o cálculo médio para melhor compreensão.
df_media_vendas = df_media_vendas.withColumnRenamed("avg(valorVenda)", "MediaVendas")

df_media_vendas.select(F.round(df_media_vendas.MediaVendas,2).alias("MediaVendas")).show()
# Out:
# +-----------+
# |MediaVendas|
# +-----------+
# |   14384.61|
# +-----------+

# %%
# Produto mais vendido
#df.select(F.max("qtd")).show()
#df.orderBy(F.desc("qtd")).select("produto", "qtd").limit(1).show()
df_qtd_max = df.groupBy("produto").max("qtd").alias("total")
df_qtd_max.orderBy(F.desc("max(qtd)")).limit(3).show()
# Out:
# +------------+--------+
# |     produto|max(qtd)|
# +------------+--------+
# |  Impressora|     100|
# |     Monitor|     100|
# |Caixa de Som|      94|
# +------------+--------+

# %%
df.groupBy("produto").sum("valorVenda").show()
# Out:
# +--------------+------------------+
# |       produto|   sum(valorVenda)|
# +--------------+------------------+
# |  Caixa de Som|130617.25622558594|
# |    Smartwatch|  56203.5029296875|
# |      Roteador|232329.25314331055|
# |        Câmera|55819.400817871094|
# |      Notebook|124600.67626953125|
# |        Tablet|218369.99731445312|
# |    Smartphone| 59875.05993652344|
# |    Impressora|139983.47662353516|
# |       Monitor| 318597.9027404785|
# |Fone de Ouvido|102064.42736816406|
# +--------------+------------------+

# %%
df2 = (
    df.groupBy("Produto")
    .sum("valorVenda")
    .show(n=10)     
)
# Out:
# +--------------+------------------+
# |       Produto|   sum(valorVenda)|
# +--------------+------------------+
# |  Caixa de Som|130617.25622558594|
# |    Smartwatch|  56203.5029296875|
# |      Roteador|232329.25314331055|
# |        Câmera|55819.400817871094|
# |      Notebook|124600.67626953125|
# |        Tablet|218369.99731445312|
# |    Smartphone| 59875.05993652344|
# |    Impressora|139983.47662353516|
# |       Monitor| 318597.9027404785|
# |Fone de Ouvido|102064.42736816406|
# +--------------+------------------+

# %%
dfduplicados = (
    df.groupBy(df.produto)
    .count()
    .filter(col("count") > 1)
    .sort("count", ascending=False)
    .limit(10)
    .show()
)
# Out:
# +--------------+-----+
# |       produto|count|
# +--------------+-----+
# |      Roteador|   19|
# |       Monitor|   13|
# |        Câmera|   10|
# |    Smartphone|   10|
# |    Impressora|   10|
# |Fone de Ouvido|   10|
# |        Tablet|    8|
# |  Caixa de Som|    7|
# |      Notebook|    7|
# |    Smartwatch|    6|
# +--------------+-----+

# %%
# Dropando dados duplicados
df.dropDuplicates().show(10)
# Out:
# +--------+----------+-------+---+------------+---------+----------+---+------------+----------+
# |nrPedido|codCliente|cliente|qtd|     produto|    custo|valorVenda| uf|      cidade|      data|
# +--------+----------+-------+---+------------+---------+----------+---+------------+----------+
# |      15|        55| Murilo| 62|Caixa de Som|5.7812743| 1095.4434| TO|      Palmas|2020-08-30|
# |       2|        93| Arthur| 85|      Câmera|26.437727| 17726.205| MA|    São Luís|2023-09-15|
# |       8|        66|   Davi| 60|  Impressora|29.419613|  9790.599| RR|Rorainópolis|2022-07-09|
# |      22|        77| Miguel| 74|    Roteador|57.236732|  8862.097| PI|    Parnaíba|2022-10-27|
# |       4|        53|  Sofia| 36|  Impressora| 86.94093| 19559.494| RJ|     Niterói|2022-12-25|
# |      12|        88|Mariana| 81|      Câmera|57.938503| 10520.511| AL|   Arapiraca|2021-03-16|
# |      23|        67| Rafael| 64|     Monitor|   65.424| 14568.646| SE|     Aracaju|2024-12-20|
# |      25|        89|    Ana| 72|      Tablet| 87.68163| 14867.963| PI|    Teresina|2022-07-27|
# |      20|        21|  Maíra|  9|    Roteador| 22.06481| 477.55905| AC|  Rio Branco|2022-04-14|
# |       1|        87|Cecília|  4|  Smartphone| 63.57274| 533.02356| DF|    Brasília|2021-10-30|
# +--------+----------+-------+---+------------+---------+----------+---+------------+----------+
# only showing top 10 rows

# %%
# 5. *Custo Médio por Estado:  - Qual é o custo médio dos produtos vendidos em cada estado?
df.select(round(F.avg(col("custo")),2).alias("custoMedio")).show()
# Out:
# +----------+
# |custoMedio|
# +----------+
# |     51.14|
# +----------+

# %%
# 6. *Total de Vendas por Cliente: Qual é o total de vendas (valor de venda) por cliente?

df_total_por_clientes = (
    df
    .groupBy("cliente")
    .agg(F.round(F.sum("valorVenda"),2).alias("totalPorCliente"))
    .withColumnRenamed("sum(valorVenda)", "totalPorCliente")
    .show(10)
)
# Out:
# +-------+---------------+
# |cliente|totalPorCliente|
# +-------+---------------+
# |   Igor|        6478.84|
# |Cecília|         533.02|
# |Rodrigo|       34623.14|
# |  Bruna|       39058.44|
# | Thiago|       54795.69|
# |   Alex|         620.81|
# | Arthur|       68451.95|
# |    Ana|       45962.66|
# |  Maíra|       10570.65|
# |   Davi|       17882.67|
# +-------+---------------+
# only showing top 10 rows

# %%
# 7. Data Mais Recente e Mais Antiga: Qual é a data mais recente e a mais antiga registrada nos dados?
df_antigo_recente = (
    df
    .select(min(df.data)
    .alias("antigo"),
    max(df.data)
    .alias("recente"))
    .show()
)
# Out:
# +----------+----------+
# |    antigo|   recente|
# +----------+----------+
# |2020-02-26|2025-02-17|
# +----------+----------+

# %%
# 8. *Quantidade de Vendas por Dia: Quantas vendas ocorreram em cada dia?
df_total_diario = (
    df
    .groupBy(date_format("data", "dd/MM/yyyy").alias("data"))
    .agg(round(sum("valorVenda"),2)
    .alias("TotalVendaDiaria"))
    .limit(10)
    .show()
)
# Out:
# +----------+----------------+
# |      data|TotalVendaDiaria|
# +----------+----------------+
# |08/01/2025|         5368.75|
# |20/12/2024|        14568.65|
# |26/05/2021|        50725.75|
# |30/10/2021|          533.02|
# |15/09/2023|        17726.21|
# |04/01/2021|         5968.55|
# |26/02/2020|        25832.82|
# |04/09/2023|        35238.35|
# |12/12/2022|        54795.69|
# |05/11/2022|          620.81|
# +----------+----------------+

# %%
# 9. *Custo Médio e Valor de Venda Médio por Produto: Qual é o custo médio e o valor de venda médio para cada produto?
df_custoMedio_vendaMedia = (
    df.groupBy("produto")    
    .agg(round(avg("custo"),2)    
    .alias("custoMedio"),
    round(avg("valorVenda"))
    .alias("receitaMedia"))
    .limit(10)
    .show()
)
# Out:
# +--------------+----------+------------+
# |       produto|custoMedio|receitaMedia|
# +--------------+----------+------------+
# |  Caixa de Som|      47.2|     18660.0|
# |    Smartwatch|     30.04|      9367.0|
# |      Roteador|     52.97|     12228.0|
# |        Câmera|     34.35|      5582.0|
# |      Notebook|     59.48|     17800.0|
# |        Tablet|     75.21|     27296.0|
# |    Smartphone|     53.88|      5988.0|
# |    Impressora|      50.1|     13998.0|
# |       Monitor|     58.78|     24508.0|
# |Fone de Ouvido|      43.2|     10206.0|
# +--------------+----------+------------+

# %%
# 10. *Porcentagem de Lucro: Qual é a porcentagem média de lucro (baseado no custo e valor de venda) em todas as vendas?
custo_venda = df.withColumn("custoTotal", (df.qtd * df.custo))
custo_venda.show()
# Out:
# +--------+----------+-------+---+------------+---------+----------+---+--------------------+----------+----------+
# |nrPedido|codCliente|cliente|qtd|     produto|    custo|valorVenda| uf|              cidade|      data|custoTotal|
# +--------+----------+-------+---+------------+---------+----------+---+--------------------+----------+----------+
# |       1|        87|Cecília|  4|  Smartphone| 63.57274| 533.02356| DF|            Brasília|2021-10-30| 254.29095|
# |       2|        93| Arthur| 85|      Câmera|26.437727| 17726.205| MA|            São Luís|2023-09-15| 2247.2068|
# |       3|        39|  Maria| 89|  Impressora|59.264214|  35238.35| RS|             Pelotas|2023-09-04|  5274.515|
# |       4|        53|  Sofia| 36|  Impressora| 86.94093| 19559.494| RJ|             Niterói|2022-12-25| 3129.8735|
# |       5|        33|  Bruna| 21|  Smartphone| 88.32472| 6005.1646| DF|            Brasília|2022-06-08| 1854.8192|
# |       6|         9|   Igor| 21|    Notebook| 65.64703|  5368.747| MG|      Belo Horizonte|2025-01-08| 1378.5876|
# |       7|        83| Camila| 75|    Notebook|54.604053| 25832.822| MS|         Três Lagoas|2020-02-26|  4095.304|
# |       8|        66|   Davi| 60|  Impressora|29.419613|  9790.599| RR|        Rorainópolis|2022-07-09| 1765.1768|
# |       9|        93| Thiago|100|     Monitor| 76.63529|  54795.69| AL|              Maceió|2022-12-12| 7663.5293|
# |      10|        87|Vitória| 61|    Roteador| 9.217255|  3558.069| AP|    Laranjal do Jari|2021-05-13| 562.25256|
# |      11|        65| Arthur| 92|      Tablet| 69.73895| 50725.746| RJ|     Duque de Caxias|2021-05-26| 6415.9834|
# |      12|        88|Mariana| 81|      Câmera|57.938503| 10520.511| AL|           Arapiraca|2021-03-16| 4693.0186|
# |      13|        91|Gustavo| 93|    Notebook|44.281532|  25964.08| RJ|             Niterói|2022-05-10| 4118.1826|
# |      14|        75|Rodrigo| 73|  Smartwatch| 60.84905| 25456.598| RO|         Porto Velho|2020-05-14| 4441.9805|
# |      15|        55| Murilo| 62|Caixa de Som|5.7812743| 1095.4434| TO|              Palmas|2020-08-30|   358.439|
# |      16|        47|Vicente| 16|      Câmera|51.396202|   5968.55| SE|Nossa Senhora do ...|2021-01-04| 822.33923|
# |      17|        77|  Maria| 35|      Câmera|28.894793| 1680.5797| AM|           Parintins|2022-08-21|1011.31775|
# |      18|        10|Vicente| 85|      Tablet| 65.93049| 44356.758| PB|          Santa Rita|2021-03-11| 5604.0913|
# |      19|         2|Isadora| 94|    Roteador|2.7279985|  462.0363| RR|        Rorainópolis|2024-02-10| 256.43185|
# |      20|        21|  Maíra|  9|    Roteador| 22.06481| 477.55905| AC|          Rio Branco|2022-04-14| 198.58328|
# +--------+----------+-------+---+------------+---------+----------+---+--------------------+----------+----------+
# only showing top 20 rows

# %%
lucro_percentual = custo_venda.withColumn("lucroPercentual", round((custo_venda.custoTotal * custo_venda.valorVenda) / 100))
lucro_percentual.show()
# Out:
# +--------+----------+-------+---+------------+---------+----------+---+--------------------+----------+----------+---------------+
# |nrPedido|codCliente|cliente|qtd|     produto|    custo|valorVenda| uf|              cidade|      data|custoTotal|lucroPercentual|
# +--------+----------+-------+---+------------+---------+----------+---+--------------------+----------+----------+---------------+
# |       1|        87|Cecília|  4|  Smartphone| 63.57274| 533.02356| DF|            Brasília|2021-10-30| 254.29095|         1355.0|
# |       2|        93| Arthur| 85|      Câmera|26.437727| 17726.205| MA|            São Luís|2023-09-15| 2247.2068|       398344.0|
# |       3|        39|  Maria| 89|  Impressora|59.264214|  35238.35| RS|             Pelotas|2023-09-04|  5274.515|      1858652.0|
# |       4|        53|  Sofia| 36|  Impressora| 86.94093| 19559.494| RJ|             Niterói|2022-12-25| 3129.8735|       612187.0|
# |       5|        33|  Bruna| 21|  Smartphone| 88.32472| 6005.1646| DF|            Brasília|2022-06-08| 1854.8192|       111385.0|
# |       6|         9|   Igor| 21|    Notebook| 65.64703|  5368.747| MG|      Belo Horizonte|2025-01-08| 1378.5876|        74013.0|
# |       7|        83| Camila| 75|    Notebook|54.604053| 25832.822| MS|         Três Lagoas|2020-02-26|  4095.304|      1057933.0|
# |       8|        66|   Davi| 60|  Impressora|29.419613|  9790.599| RR|        Rorainópolis|2022-07-09| 1765.1768|       172821.0|
# |       9|        93| Thiago|100|     Monitor| 76.63529|  54795.69| AL|              Maceió|2022-12-12| 7663.5293|      4199284.0|
# |      10|        87|Vitória| 61|    Roteador| 9.217255|  3558.069| AP|    Laranjal do Jari|2021-05-13| 562.25256|        20005.0|
# |      11|        65| Arthur| 92|      Tablet| 69.73895| 50725.746| RJ|     Duque de Caxias|2021-05-26| 6415.9834|      3254556.0|
# |      12|        88|Mariana| 81|      Câmera|57.938503| 10520.511| AL|           Arapiraca|2021-03-16| 4693.0186|       493730.0|
# |      13|        91|Gustavo| 93|    Notebook|44.281532|  25964.08| RJ|             Niterói|2022-05-10| 4118.1826|      1069248.0|
# |      14|        75|Rodrigo| 73|  Smartwatch| 60.84905| 25456.598| RO|         Porto Velho|2020-05-14| 4441.9805|      1130777.0|
# |      15|        55| Murilo| 62|Caixa de Som|5.7812743| 1095.4434| TO|              Palmas|2020-08-30|   358.439|         3926.0|
# |      16|        47|Vicente| 16|      Câmera|51.396202|   5968.55| SE|Nossa Senhora do ...|2021-01-04| 822.33923|        49082.0|
# |      17|        77|  Maria| 35|      Câmera|28.894793| 1680.5797| AM|           Parintins|2022-08-21|1011.31775|        16996.0|
# |      18|        10|Vicente| 85|      Tablet| 65.93049| 44356.758| PB|          Santa Rita|2021-03-11| 5604.0913|      2485793.0|
# |      19|         2|Isadora| 94|    Roteador|2.7279985|  462.0363| RR|        Rorainópolis|2024-02-10| 256.43185|         1185.0|
# |      20|        21|  Maíra|  9|    Roteador| 22.06481| 477.55905| AC|          Rio Branco|2022-04-14| 198.58328|          948.0|
# +--------+----------+-------+---+------------+---------+----------+---+--------------------+----------+----------+---------------+
# only showing top 20 rows

# %% [markdown]
# # Trabalhando com datas

# %%
#11) Data Mais Recente e Mais Antiga: Objetivo: Descobrir qual é a data mais recente e a mais antiga registrada nos dados.

data_recente_antiga = (
    df.select(
        F.max(date_format(df.data, "dd/MM/yyyy"))
        .alias("dataAntiga"), 
        F.min(date_format("data", "dd/MM/yyyy"))
        .alias("dataRecente"))
)

data_recente_antiga.show()
# Out:
# +----------+-----------+
# |dataAntiga|dataRecente|
# +----------+-----------+
# |31/07/2020| 01/05/2020|
# +----------+-----------+

# %%
df.select(F.min(df.data).alias("dataAntiga")).show()
# Out:
# +----------+
# |dataAntiga|
# +----------+
# |2020-02-26|
# +----------+

# %%
# 12) Quantidade de Vendas por Dia. Objetivo: Contar quantas vendas ocorreram em cada dia.
#df.groupBy("data").agg(sum("qtd").alias("qtdDia")).show()
df_qtdDia = (
    df.groupBy("data")
    .agg(sum("qtd").alias("qtdDia"))    
    .sort("data")
)

df_qtdDia.show()
# Out:
# +----------+------+
# |      data|qtdDia|
# +----------+------+
# |2020-02-26|    75|
# |2020-05-01|    41|
# |2020-05-14|    73|
# |2020-05-18|     8|
# |2020-07-31|    50|
# |2020-08-30|    62|
# |2020-10-20|   155|
# |2020-12-01|    19|
# |2020-12-12|    51|
# |2021-01-04|    16|
# |2021-01-11|    79|
# |2021-01-28|    24|
# |2021-02-16|    76|
# |2021-02-18|    92|
# |2021-02-22|    75|
# |2021-02-26|    73|
# |2021-03-07|    41|
# |2021-03-11|    85|
# |2021-03-16|    81|
# |2021-03-18|    20|
# +----------+------+
# only showing top 20 rows

# %% [markdown]
# ### Adicionar Coluna com Ano e Mês. Objetivo: Adicionar uma coluna que contenha apenas o ano e o mês da data da venda.

# %%
# 13) Adicionar Coluna com Ano e Mês Objetivo: Adicionar uma coluna que contenha apenas o ano e o mês da data da venda.
df_ano_mes = df.withColumn("ano_mes", date_format(df.data, "yyyy-MM"))
df_ano_mes.show()
# Out:
# +--------+----------+-------+---+------------+---------+----------+---+--------------------+----------+-------+
# |nrPedido|codCliente|cliente|qtd|     produto|    custo|valorVenda| uf|              cidade|      data|ano_mes|
# +--------+----------+-------+---+------------+---------+----------+---+--------------------+----------+-------+
# |       1|        87|Cecília|  4|  Smartphone| 63.57274| 533.02356| DF|            Brasília|2021-10-30|2021-10|
# |       2|        93| Arthur| 85|      Câmera|26.437727| 17726.205| MA|            São Luís|2023-09-15|2023-09|
# |       3|        39|  Maria| 89|  Impressora|59.264214|  35238.35| RS|             Pelotas|2023-09-04|2023-09|
# |       4|        53|  Sofia| 36|  Impressora| 86.94093| 19559.494| RJ|             Niterói|2022-12-25|2022-12|
# |       5|        33|  Bruna| 21|  Smartphone| 88.32472| 6005.1646| DF|            Brasília|2022-06-08|2022-06|
# |       6|         9|   Igor| 21|    Notebook| 65.64703|  5368.747| MG|      Belo Horizonte|2025-01-08|2025-01|
# |       7|        83| Camila| 75|    Notebook|54.604053| 25832.822| MS|         Três Lagoas|2020-02-26|2020-02|
# |       8|        66|   Davi| 60|  Impressora|29.419613|  9790.599| RR|        Rorainópolis|2022-07-09|2022-07|
# |       9|        93| Thiago|100|     Monitor| 76.63529|  54795.69| AL|              Maceió|2022-12-12|2022-12|
# |      10|        87|Vitória| 61|    Roteador| 9.217255|  3558.069| AP|    Laranjal do Jari|2021-05-13|2021-05|
# |      11|        65| Arthur| 92|      Tablet| 69.73895| 50725.746| RJ|     Duque de Caxias|2021-05-26|2021-05|
# |      12|        88|Mariana| 81|      Câmera|57.938503| 10520.511| AL|           Arapiraca|2021-03-16|2021-03|
# |      13|        91|Gustavo| 93|    Notebook|44.281532|  25964.08| RJ|             Niterói|2022-05-10|2022-05|
# |      14|        75|Rodrigo| 73|  Smartwatch| 60.84905| 25456.598| RO|         Porto Velho|2020-05-14|2020-05|
# |      15|        55| Murilo| 62|Caixa de Som|5.7812743| 1095.4434| TO|              Palmas|2020-08-30|2020-08|
# |      16|        47|Vicente| 16|      Câmera|51.396202|   5968.55| SE|Nossa Senhora do ...|2021-01-04|2021-01|
# |      17|        77|  Maria| 35|      Câmera|28.894793| 1680.5797| AM|           Parintins|2022-08-21|2022-08|
# |      18|        10|Vicente| 85|      Tablet| 65.93049| 44356.758| PB|          Santa Rita|2021-03-11|2021-03|
# |      19|         2|Isadora| 94|    Roteador|2.7279985|  462.0363| RR|        Rorainópolis|2024-02-10|2024-02|
# |      20|        21|  Maíra|  9|    Roteador| 22.06481| 477.55905| AC|          Rio Branco|2022-04-14|2022-04|
# +--------+----------+-------+---+------------+---------+----------+---+--------------------+----------+-------+
# only showing top 20 rows

# %%
# 14) Filtrar Vendas de um Mês Específico. Objetivo: Filtrar todas as vendas que ocorreram no mês de julho de 2024.
df.filter((year(col("data")) == 2024) & (month(col("data")) == 6)).show(10)
# Out:
# +--------+----------+-------+---+-------+-----+----------+---+------+----+
# |nrPedido|codCliente|cliente|qtd|produto|custo|valorVenda| uf|cidade|data|
# +--------+----------+-------+---+-------+-----+----------+---+------+----+
# +--------+----------+-------+---+-------+-----+----------+---+------+----+

# %% [markdown]
# #### Adicionar Coluna com Dia da Semana. Objetivo: Adicionar uma coluna que mostre o dia da semana para cada data de venda.

# %%
# 15) Adicionar Coluna com Dia da Semana. Objetivo: Adicionar uma coluna que mostre o dia da semana para cada data de venda.
df_dia_semana = df.withColumn("dia_semana", date_format(df.data, "EEEE"))
df_dia_semana.show()
# Out:
# +--------+----------+-------+---+------------+---------+----------+---+--------------------+----------+----------+
# |nrPedido|codCliente|cliente|qtd|     produto|    custo|valorVenda| uf|              cidade|      data|dia_semana|
# +--------+----------+-------+---+------------+---------+----------+---+--------------------+----------+----------+
# |       1|        87|Cecília|  4|  Smartphone| 63.57274| 533.02356| DF|            Brasília|2021-10-30|  Saturday|
# |       2|        93| Arthur| 85|      Câmera|26.437727| 17726.205| MA|            São Luís|2023-09-15|    Friday|
# |       3|        39|  Maria| 89|  Impressora|59.264214|  35238.35| RS|             Pelotas|2023-09-04|    Monday|
# |       4|        53|  Sofia| 36|  Impressora| 86.94093| 19559.494| RJ|             Niterói|2022-12-25|    Sunday|
# |       5|        33|  Bruna| 21|  Smartphone| 88.32472| 6005.1646| DF|            Brasília|2022-06-08| Wednesday|
# |       6|         9|   Igor| 21|    Notebook| 65.64703|  5368.747| MG|      Belo Horizonte|2025-01-08| Wednesday|
# |       7|        83| Camila| 75|    Notebook|54.604053| 25832.822| MS|         Três Lagoas|2020-02-26| Wednesday|
# |       8|        66|   Davi| 60|  Impressora|29.419613|  9790.599| RR|        Rorainópolis|2022-07-09|  Saturday|
# |       9|        93| Thiago|100|     Monitor| 76.63529|  54795.69| AL|              Maceió|2022-12-12|    Monday|
# |      10|        87|Vitória| 61|    Roteador| 9.217255|  3558.069| AP|    Laranjal do Jari|2021-05-13|  Thursday|
# |      11|        65| Arthur| 92|      Tablet| 69.73895| 50725.746| RJ|     Duque de Caxias|2021-05-26| Wednesday|
# |      12|        88|Mariana| 81|      Câmera|57.938503| 10520.511| AL|           Arapiraca|2021-03-16|   Tuesday|
# |      13|        91|Gustavo| 93|    Notebook|44.281532|  25964.08| RJ|             Niterói|2022-05-10|   Tuesday|
# |      14|        75|Rodrigo| 73|  Smartwatch| 60.84905| 25456.598| RO|         Porto Velho|2020-05-14|  Thursday|
# |      15|        55| Murilo| 62|Caixa de Som|5.7812743| 1095.4434| TO|              Palmas|2020-08-30|    Sunday|
# |      16|        47|Vicente| 16|      Câmera|51.396202|   5968.55| SE|Nossa Senhora do ...|2021-01-04|    Monday|
# |      17|        77|  Maria| 35|      Câmera|28.894793| 1680.5797| AM|           Parintins|2022-08-21|    Sunday|
# |      18|        10|Vicente| 85|      Tablet| 65.93049| 44356.758| PB|          Santa Rita|2021-03-11|  Thursday|
# |      19|         2|Isadora| 94|    Roteador|2.7279985|  462.0363| RR|        Rorainópolis|2024-02-10|  Saturday|
# |      20|        21|  Maíra|  9|    Roteador| 22.06481| 477.55905| AC|          Rio Branco|2022-04-14|  Thursday|
# +--------+----------+-------+---+------------+---------+----------+---+--------------------+----------+----------+
# only showing top 20 rows

# %%
# 16) Determinar o Dia da Semana com Mais Vendas
# Objetivo: Descobrir qual dia da semana teve o maior número de vendas totais (soma das quantidades vendidas).

df_dia_semana_total_qtd = (
    df_dia_semana
    .groupBy("dia_semana")
    .agg(sum("qtd").alias("qtd"))
    .sort("qtd", ascending=False)    
)
df_dia_semana_total_qtd.show()
# Out:
# +----------+----+
# |dia_semana| qtd|
# +----------+----+
# |   Tuesday|1096|
# |    Sunday| 965|
# | Wednesday| 790|
# |  Thursday| 673|
# |    Monday| 652|
# |    Friday| 641|
# |  Saturday| 570|
# +----------+----+

# %%
# 17) Calcular a Média de Vendas por Mês:
# Objetivo: Calcular a média da quantidade de vendas realizadas em cada mês.

df_media_vendas_mes = (
    df.groupBy(month("data")
               .alias("MesCorrespondente"))
    .agg(round(F.avg("valorVenda"),2)
         .alias("TotalPorMes"))
)
df_media_vendas_mes.show()
# Out:
# +-----------------+-----------+
# |MesCorrespondente|TotalPorMes|
# +-----------------+-----------+
# |               12|   15353.77|
# |                1|    7462.61|
# |                6|   25879.79|
# |                3|    15428.6|
# |                5|   14905.89|
# |                9|   14914.15|
# |                4|   13396.67|
# |                8|   12865.41|
# |                7|    6835.11|
# |               10|   11716.91|
# |               11|   14776.19|
# |                2|   22506.13|
# +-----------------+-----------+

# %%
#Exercício 20: Calcular a Média de Vendas por Produto em Cada Ano 
# Objetivo: Calcular a média de vendas realizadas para cada produto em cada ano. Utilize uma estrutura de repetição para iterar sobre os anos e calcular a média das vendas.

ano_venda = df.select(year(df.data).alias("ano")).distinct().sort("data").collect()

# %%
print(ano_venda)
# Out:
# [Row(ano=2020), Row(ano=2021), Row(ano=2022), Row(ano=2023), Row(ano=2024), Row(ano=2025)]

# %%
df_weekend = df.withColumn("dia_semana", date_format(df.data, "EEEE"))
df_weekend.filter((df_weekend.dia_semana ==  "Saturday") | (df_weekend.dia_semana == "Sunday")).show()
# Out:
# +--------+----------+---------+---+--------------+---------+----------+---+----------------+----------+----------+
# |nrPedido|codCliente|  cliente|qtd|       produto|    custo|valorVenda| uf|          cidade|      data|dia_semana|
# +--------+----------+---------+---+--------------+---------+----------+---+----------------+----------+----------+
# |       1|        87|  Cecília|  4|    Smartphone| 63.57274| 533.02356| DF|        Brasília|2021-10-30|  Saturday|
# |       4|        53|    Sofia| 36|    Impressora| 86.94093| 19559.494| RJ|         Niterói|2022-12-25|    Sunday|
# |       8|        66|     Davi| 60|    Impressora|29.419613|  9790.599| RR|    Rorainópolis|2022-07-09|  Saturday|
# |      15|        55|   Murilo| 62|  Caixa de Som|5.7812743| 1095.4434| TO|          Palmas|2020-08-30|    Sunday|
# |      17|        77|    Maria| 35|        Câmera|28.894793| 1680.5797| AM|       Parintins|2022-08-21|    Sunday|
# |      19|         2|  Isadora| 94|      Roteador|2.7279985|  462.0363| RR|    Rorainópolis|2024-02-10|  Saturday|
# |      21|        49|  Eduardo| 79|Fone de Ouvido| 31.70819|  7979.518| PA|      Ananindeua|2021-09-12|    Sunday|
# |      24|        74|     Alex| 14|    Impressora| 26.07477|  620.8079| MT|          Cuiabá|2022-11-05|  Saturday|
# |      27|        12|     Theo| 51|  Caixa de Som|38.939976|  7168.962| AP|Laranjal do Jari|2020-12-12|  Saturday|
# |      29|        56|   Talita| 21|Fone de Ouvido|5.8780384|   652.781| RS|    Porto Alegre|2024-09-22|    Sunday|
# |      32|        67|    Luísa| 33|      Notebook|93.506424|  5276.718| ES|      Vila Velha|2024-02-18|    Sunday|
# |      34|        36|    Bruna| 87|        Tablet|61.323513| 14820.397| CE|         Caucaia|2023-12-30|  Saturday|
# |      38|        48|Guilherme|  2|    Smartphone| 79.17543|  548.0267| AM|       Parintins|2022-04-23|  Saturday|
# |      40|         2|  Rodrigo| 44|        Câmera| 74.41133| 7354.8174| SC|       Joinville|2024-08-04|    Sunday|
# |      46|         9|   Helena| 57|    Smartphone| 88.87871| 11873.143| PR|        Londrina|2022-08-21|    Sunday|
# |      47|        83| Carolina| 92|        Tablet| 81.44373| 13166.304| PB|  Campina Grande|2023-04-30|    Sunday|
# |      51|        47|    Sofia| 84|        Tablet|82.419365| 45754.418| PR|        Londrina|2023-06-18|    Sunday|
# |      64|        32|   Helena| 18|      Roteador| 53.58265| 3897.4446| RJ|  Rio de Janeiro|2022-01-22|  Saturday|
# |      65|        82|    Bruna| 41|  Caixa de Som| 72.01753| 18232.879| RS|    Porto Alegre|2021-03-07|    Sunday|
# |      68|        24|   Camila|  1|    Smartphone|  55.8773| 206.96252| AM|          Manaus|2022-07-09|  Saturday|
# +--------+----------+---------+---+--------------+---------+----------+---+----------------+----------+----------+
# only showing top 20 rows

# %%
df.filter(F.col("uf") == "SP").limit(3).show()
# Out:
# +--------+----------+-------+---+----------+---------+----------+---+--------------------+----------+
# |nrPedido|codCliente|cliente|qtd|   produto|    custo|valorVenda| uf|              cidade|      data|
# +--------+----------+-------+---+----------+---------+----------+---+--------------------+----------+
# |      53|        99| Lorena| 63|Smartwatch| 7.628842| 1882.5494| SP|            Campinas|2024-08-27|
# |      62|         1|  Maíra| 94|Impressora|29.035501| 10093.088| SP|            Campinas|2021-09-14|
# |      66|        94|  Elisa| 69|  Roteador|56.019424| 20709.803| SP|São Bernardo do C...|2022-02-28|
# +--------+----------+-------+---+----------+---------+----------+---+--------------------+----------+

# %% [markdown]
#
#
#
#
#
#
# 24. Ticket Médio por Cliente
#    - Calcule o ticket médio por cliente, considerando a soma do `valorVenda` dividida pelo número de pedidos.
#
# 25. Comparação de Faturamento por Cidade
#    - Para cada estado, encontre a cidade com o maior faturamento total.
#
# 26. Identificar Vendas com Prejuízo
#    - Liste todas as vendas onde o custo (`custo * qtd`) foi maior que o valor de venda (`valorVenda * qtd`).
#
# 27. Clientes que Compraram Apenas Uma Vez
#    - Encontre os clientes que realizaram apenas um pedido no e-commerce.
#
# 28. Produto Mais Vendido em Cada Estado
#    - Descubra qual produto teve a maior quantidade vendida em cada estado (`uf`).
#
# 29. Crescimento Mensal do Faturamento
#    - Calcule o crescimento percentual do faturamento mês a mês.
#
# 30. Cliente com Maior Ticket Médio
#    - Encontre o cliente que possui o maior ticket médio, considerando apenas aqueles que realizaram pelo menos 5 compras.

# %%
#21. Clientes com Mais Compras  
#   Identifique os 5 clientes que mais realizaram compras, considerando a quantidade total de itens (`qtd`). 

df.orderBy(F.col("qtd").desc()).limit(5).show()
# Out:
# +--------+----------+-------+---+------------+---------+----------+---+----------+----------+
# |nrPedido|codCliente|cliente|qtd|     produto|    custo|valorVenda| uf|    cidade|      data|
# +--------+----------+-------+---+------------+---------+----------+---+----------+----------+
# |       9|        93| Thiago|100|     Monitor| 76.63529|  54795.69| AL|    Maceió|2022-12-12|
# |      80|        92|Natália|100|  Impressora| 61.07266|  35903.55| AL|    Maceió|2021-08-06|
# |      45|       100| Helena| 97|     Monitor|47.510635| 20679.254| SE|   Lagarto|2023-09-05|
# |      62|         1|  Maíra| 94|  Impressora|29.035501| 10093.088| SP|  Campinas|2021-09-14|
# |      43|        42|   Levi| 94|Caixa de Som| 85.15262| 50336.234| ES|Vila Velha|2020-10-20|
# +--------+----------+-------+---+------------+---------+----------+---+----------+----------+

# %%
#22. Estados com Maior Receita  
# Liste os estados (`uf`) ordenados pela maior receita total (`valorVenda`). 

df.orderBy(F.col("valorVenda").desc()).limit(10).show()
# Out:
# +--------+----------+--------+---+--------------+---------+----------+---+---------------+----------+
# |nrPedido|codCliente| cliente|qtd|       produto|    custo|valorVenda| uf|         cidade|      data|
# +--------+----------+--------+---+--------------+---------+----------+---+---------------+----------+
# |      92|        40|   Tomás| 78|       Monitor| 98.33024|  55954.54| DF|       Brasília|2025-02-02|
# |      91|        42|   Lucas| 76|      Roteador| 91.73759| 55206.703| AM|    Itacoatiara|2021-02-16|
# |       9|        93|  Thiago|100|       Monitor| 76.63529|  54795.69| AL|         Maceió|2022-12-12|
# |      11|        65|  Arthur| 92|        Tablet| 69.73895| 50725.746| RJ|Duque de Caxias|2021-05-26|
# |      43|        42|    Levi| 94|  Caixa de Som| 85.15262| 50336.234| ES|     Vila Velha|2020-10-20|
# |      89|        89| Vitória| 92|      Notebook| 97.32778| 48521.945| PR|       Londrina|2023-08-06|
# |      67|        87|Henrique| 92|       Monitor|67.514824|  47526.32| CE|      Fortaleza|2021-02-18|
# |      51|        47|   Sofia| 84|        Tablet|82.419365| 45754.418| PR|       Londrina|2023-06-18|
# |      18|        10| Vicente| 85|        Tablet| 65.93049| 44356.758| PB|     Santa Rita|2021-03-11|
# |      97|        98| Melissa| 62|Fone de Ouvido| 97.96422|  37341.48| MG|     Uberlândia|2024-04-05|
# +--------+----------+--------+---+--------------+---------+----------+---+---------------+----------+

# %%
# 23. Produtos com Maior Faturamento  
#   - Quais são os 5 produtos que geraram o maior faturamento total (`valorVenda * qtd`)?  

df_faturamento = df.withColumn("total", df.valorVenda * df.qtd)

# %%
#df_faturamento.groupBy(df_faturamento.produto).agg(round(F.sum("total"),2).alias("total")).show()
df_faturamento.groupBy("produto") \
    .agg(F.round(F.sum("total"), 2).alias("total")) \
    .orderBy(F.desc("total")) \
    .show()
# Out:
# +--------------+-------------+
# |       produto|        total|
# +--------------+-------------+
# |       Monitor|2.626524907E7|
# |        Tablet|1.796033289E7|
# |      Roteador|1.382558125E7|
# |    Impressora| 1.02261446E7|
# |  Caixa de Som|   9825723.35|
# |      Notebook|   9776098.78|
# |Fone de Ouvido|   6646714.47|
# |    Smartphone|   3879940.17|
# |    Smartwatch|   3577746.59|
# |        Câmera|   3339057.64|
# +--------------+-------------+
